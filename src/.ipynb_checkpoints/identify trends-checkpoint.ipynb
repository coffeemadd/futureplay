# %%
import re, gensim, pickle, operator
import pandas as pd
import numpy as np
import networkx as nx
import seaborn as sns
from datetime import datetime
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline

# %%
# load data
data_folder = '../data/csv_export/'
util_folder = '../util/'
trend_folder = '../data/trends/'
df_organizations = pd.read_csv(data_folder + 'organizations.csv'.format(data_folder), dtype={'first_funding_on': str, 'last_funding_on':str})
df_description = pd.read_csv(data_folder + 'organization_descriptions.csv')
df_funding_rounds = pd.read_csv(data_folder + 'funding_rounds.csv')
df_funds = pd.read_csv(data_folder + 'funds.csv')
df_investments = pd.read_csv(data_folder + 'investments.csv')
df_acq = pd.read_csv(data_folder + 'acquisitions.csv')
df_competition = pd.read_csv(data_folder + 'competitors.csv')
df_category = pd.read_csv(data_folder + 'category_groups.csv')
df_investors = pd.read_csv(data_folder + 'investors.csv')

# %%
# 각 카테고리에 속하는 회사들의 펀딩 찍어보기
# 회사-카테고리 매핑
df_category = df_organizations[['uuid','category_list']]
print(df_category.head())
# Out:
#                                    uuid  \
# 0  1e4f199c-363b-451b-a164-f94571075ee5
# 1  6681b1b0-0cea-6a4a-820d-60b15793fa66
# 2  fd80725f-53fc-7009-9878-aeecf1e9ffbb
# 3  10a3b2fd-b142-046b-7d8f-3b1aa4877aca
# 4  1d410d6c-13ce-3d53-4e3f-be70dd5ffd54
#
#                                        category_list
# 0  hardware|manufacturing|product design|semicond...
# 1                                  hardware|software
# 2  cloud computing|collaboration|developer tools|...
# 3           hardware|information technology|software
# 4               computer|government|service industry

# %%
# 카테고리 리스트를 개별 카테고리로 나눠서 dataframe 으로 만든다
df2 = df_category['category_list'].str.split('|').apply(pd.Series, 1).stack()
df2.index = df2.index.droplevel(-1)
df2.name = 'category_list'
del df_category['category_list']
df_category = df_category.join(df2)
df_category.columns = ['uuid', 'category']
df_category.head()
# Out:
#                                    uuid        category
# 0  1e4f199c-363b-451b-a164-f94571075ee5        hardware
# 0  1e4f199c-363b-451b-a164-f94571075ee5   manufacturing
# 0  1e4f199c-363b-451b-a164-f94571075ee5  product design
# 0  1e4f199c-363b-451b-a164-f94571075ee5   semiconductor
# 1  6681b1b0-0cea-6a4a-820d-60b15793fa66        hardware

# %%
# 각 회사의 투자 정보를 불러온다
df_funding = df_funding_rounds[['company_uuid', 'funding_round_uuid', 'announced_on']]
df_funding = df_funding.merge(df_category, left_on = 'company_uuid', right_on = 'uuid', how = 'inner')
df_funding = df_funding.drop('uuid', axis = 1)
df_funding.columns = ['company_uuid', 'funding_round_uuid', 'date', 'category']
df_funding['year-month'] = df_funding['date'].str[:7]
df_funding.head()
# Out:
#                            company_uuid                    funding_round_uuid  \
# 0  4f503d57-bf03-4010-6fcc-036fab95b39c  d17ab961-d739-410e-e904-4cb78057cbe1
# 1  4f503d57-bf03-4010-6fcc-036fab95b39c  d17ab961-d739-410e-e904-4cb78057cbe1
# 2  4f503d57-bf03-4010-6fcc-036fab95b39c  2dd15d97-767c-4eb4-6053-c7a7ce203801
# 3  4f503d57-bf03-4010-6fcc-036fab95b39c  2dd15d97-767c-4eb4-6053-c7a7ce203801
# 4  bb971d77-d7b8-a3c3-6925-c418077e5d3c  828b3a89-451e-cd0a-6d57-e31dd6a46124
#
#          date            category year-month
# 0  2017-07-04  financial services    2017-07
# 1  2017-07-04             fintech    2017-07
# 2  2016-03-15  financial services    2016-03
# 3  2016-03-15             fintech    2016-03
# 4  2017-07-04  financial services    2017-07

# %%
# 각 회사에 투자한 투자사들의 정보를 합친다
df_investment = pd.DataFrame(df_investments[['funding_round_uuid', 'investor_uuid']].groupby('funding_round_uuid')['investor_uuid'].apply(list)).reset_index()
df_funding = df_funding.merge(df_investment, on = 'funding_round_uuid')
df_funding.head()
# Out:
#                            company_uuid                    funding_round_uuid  \
# 0  4f503d57-bf03-4010-6fcc-036fab95b39c  d17ab961-d739-410e-e904-4cb78057cbe1
# 1  4f503d57-bf03-4010-6fcc-036fab95b39c  d17ab961-d739-410e-e904-4cb78057cbe1
# 2  4f503d57-bf03-4010-6fcc-036fab95b39c  2dd15d97-767c-4eb4-6053-c7a7ce203801
# 3  4f503d57-bf03-4010-6fcc-036fab95b39c  2dd15d97-767c-4eb4-6053-c7a7ce203801
# 4  bb971d77-d7b8-a3c3-6925-c418077e5d3c  828b3a89-451e-cd0a-6d57-e31dd6a46124
#
#          date            category year-month  \
# 0  2017-07-04  financial services    2017-07
# 1  2017-07-04             fintech    2017-07
# 2  2016-03-15  financial services    2016-03
# 3  2016-03-15             fintech    2016-03
# 4  2017-07-04  financial services    2017-07
#
#                                        investor_uuid
# 0  [1d91db1b-8aa3-3a98-aca1-b375b327235b, 307c51d...
# 1  [1d91db1b-8aa3-3a98-aca1-b375b327235b, 307c51d...
# 2  [307c51d2-b1f2-315a-9dcc-87643466bb87, 8ea4648...
# 3  [307c51d2-b1f2-315a-9dcc-87643466bb87, 8ea4648...
# 4  [4ede174d-3254-8602-e977-d9c0bfe34433, 94c2fe4...

# %%
# 가장 많이 사용된 탑 10 카테고리
df_category_count = pd.read_csv('../data/others/category_count.csv')
print(df_category_count.head(20))

# # csv 파일이 없을 시 다음의 코드로 저장할 수 있다
# df_funding.groupby('category').size().rename('count').reset_index().sort_values('count', ascending = False).to_csv('../data/others/category_count.csv', index = False)
# Out:
#                   category  count
# 0                 software  15892
# 1                   mobile  12275
# 2              health care  10972
# 3      enterprise software   9600
# 4               e-commerce   9173
# 5                 internet   8314
# 6            biotechnology   7931
# 7   information technology   6659
# 8                     saas   6240
# 9                analytics   5959
# 10             advertising   4872
# 11           manufacturing   4829
# 12                 medical   4767
# 13                    apps   4493
# 14            social media   4357
# 15               education   3717
# 16                 finance   3650
# 17                big data   3482
# 18                 fintech   3348
# 19                hardware   3257

# %%
# crunchbase 의 카테고리 정보로 빠른 투자자들 찾기
def get_early_investors_by_categories(categories, early_investment_percent = 10, top_k = 30,verbose = True):
    color1 = 'blue'
    if type(categories) == str:
        categories = [categories]

    # 펀딩 정보중 겹치는 데이터를 뺀다
    df = df_funding[df_funding['category'].isin(categories)].drop_duplicates('funding_round_uuid')
    print df.shape
    if df.shape[0] == 0:
        if verbose:
            print 'not found in categories'
        return
    
    # 그래프를 그리기 위한 전처리
    start_year = min(df['year-month'].values)[:4]
    count = df.groupby('year-month').size().rename('count').reset_index()
    for year in range(int(start_year), 2018):
        year = str(year)
        if count[count['year-month'] == '{}-01'.format(year)].shape[0] == 0:
            count.loc[-1] = ['{}-01'.format(year), 0]
            count.index = count.index + 1
    count['year'] = np.where(True, count['year-month'].str[:4], '')
    count = count.sort_values('year-month')
    count['cum_count'] = count['count'].cumsum()
    if verbose:
        valid_categories = list(set(list(df_funding['category'].unique())).intersection(set(categories)))
        print('Relevant categories: {}'.format(valid_categories))

    # 가장 빠른 상위 top_k 퍼센트의 투자만 고른다
    dates = sorted(df['date'].values, reverse = False)
    fast_date = dates[int(float(early_investment_percent) / 100 * len(dates))]
    if verbose:
        print "Early {} percent investors before {} \n({} early fundings out of {} total)".format(early_investment_percent, fast_date, int(float(early_investment_percent) / 100 * len(dates)), len(dates))
    df_fast = df[df['date'] < fast_date]
    
    # 투자자 리스트를 개별 투자자의 형태로 dataframe 을 변형한다
    df_fast2 = df_fast['investor_uuid'].apply(pd.Series, 1).stack()
    df_fast2.index = df_fast2.index.droplevel(-1)
    df_fast2.name = 'investor_uuid'
    del df_fast['investor_uuid']
    df_fast = df_fast.join(df_fast2)
    
    # 첫 투자 날을 기억해
    df_fast3 = df_fast.groupby('investor_uuid')['year-month'].min().rename('date').reset_index()

    # 가장 많은 투자를 한 투자자 순으로 출력한다
    score = df_fast.groupby('investor_uuid').size().rename('count').reset_index().sort_values('count', ascending = False)
    score = score.merge(df_investors[['investor_name', 'uuid']], how = 'inner', left_on = 'investor_uuid', right_on = 'uuid')
    score = score.merge(df_fast3, on = 'investor_uuid')
    score2 = score.drop(['investor_uuid', 'uuid'], axis = 1)
    if verbose:
        print score2.head(top_k)
        print score2.shape
        count[['year-month', 'cum_count']].plot(x = count['year'], linestyle = '-', color = [color1], fontsize = 25, figsize = (30, 8)).legend(loc = 2, fontsize = 20, labels = ['funding count'])
    return score

# %%
# company description 에 있는 단어 기반으로 해당 단어에 관련된 회사들에 빨리 투자한 투자자 찾기
def get_early_investors_by_words(words, early_investment_percent = 10, top_k = 30, expand = False, verbose = True):
    color1 = 'blue'
    
    # load required dataset
    if 'word2company' not in globals():
        print('loading word2company')
        global word2company
        word2company = pickle.load(open(util_folder + 'word2company.pickle'))
    if 'model' not in globals():
        print('loading word2vec model')
        global model
        model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')

    # 연관 단어도 같이 보고 싶을 시 비슷한 단어를 검색에 포함시킨다
    # train 된 word2vec 을 사용하여 관련도가 높은 단어들을 포함한다
    final_words = []
    if type(words) == str:
        words = [words]
    for word in words:
        if ' ' in word:
            word = word.replace(' ', '_')
        if expand:
            if word not in model: continue
            _words = model.most_similar(word)
            _words = [str(_word) for _word, sim in _words]
            final_words.extend(_words)
        final_words.append(word)
    final_words = list(set(final_words))
    
    # 해당 단어가 있는 회사들을 모은다
    companies = []
    for word in final_words:
        _companies = word2company.get(word, [])
        companies.extend(_companies)
    companies = list(set(companies))

    # 펀딩 정보중 필요한 회사들만 취하고, 겹치는 데이터를 뺀다
    df = df_funding[df_funding['company_uuid'].isin(companies)].drop_duplicates('funding_round_uuid')    
    if df.shape[0] < 10:
        return None
    
    # 그래프를 그리기 위한 전처리
    start_year = min(df['year-month'].values)[:4]
    count = df.groupby('year-month').size().rename('count').reset_index()
    for year in range(int(start_year), 2018):
        year = str(year)
        if count[count['year-month'] == '{}-01'.format(year)].shape[0] == 0:
            count.loc[-1] = ['{}-01'.format(year), 0]
            count.index = count.index + 1
    count['year'] = np.where(True, count['year-month'].str[:4], '')
    count = count.sort_values('year-month')
    count['cum_count'] = count['count'].cumsum()
    if verbose:
        print('Keywords: {}'.format(final_words))

    # 가장 빠른 상위 top_k 퍼센트의 투자만 고른다
    dates = sorted(df['date'].values, reverse = False)
    fast_date = dates[int(float(early_investment_percent) / 100 * len(dates))]
    if verbose:    
        print "Early {} percent investors before {} \n({} early fundings out of {} total)".format(early_investment_percent, fast_date, int(float(early_investment_percent) / 100 * len(dates)), len(dates))
    df_fast = df[df['date'] < fast_date]
    
    # 투자자 리스트를 개별 투자자의 형태로 dataframe 을 변형한다
    try:
        df_fast2 = df_fast['investor_uuid'].apply(pd.Series, 1).stack()
    except Exception as e:
        print 'none'
        return None
        
        
    df_fast2.index = df_fast2.index.droplevel(-1)
    df_fast2.name = 'investor_uuid'
    del df_fast['investor_uuid']
    df_fast = df_fast.join(df_fast2)
    
    # 첫 투자 날을 기억해
    df_fast3 = df_fast.groupby('investor_uuid')['year-month'].min().rename('date').reset_index()

    # 가장 많은 투자를 한 투자자 순으로 출력한다
    score = df_fast.groupby('investor_uuid').size().rename('count').reset_index().sort_values('count', ascending = False)
    score = score.merge(df_investors[['investor_name', 'uuid']], how = 'inner', left_on = 'investor_uuid', right_on = 'uuid')
    score = score.merge(df_fast3, on = 'investor_uuid')
    score2 = score.drop(['investor_uuid', 'uuid'], axis = 1)
    if verbose:        
        print score2.head(top_k)
        print score2.shape
        count[['year-month', 'cum_count']].plot(x = count['year'], linestyle = '-', color = [color1], fontsize = 25, figsize = (30, 8)).legend(loc = 2, fontsize = 20, labels = ['funding count'])
    return score

# %%
def get_early_investors(words, early_investment_percent = 10, top_k = 30):
    get_early_investors_by_categories(words, early_investment_percent = 10, top_k = 30)
    get_early_investors_by_words(words, early_investment_percent = 10, top_k = 30)

# %%
# crunchbase 의 카테고리 정보로 빠른 투자자 vs 전체 그려보기
def plot_early_investors(category, weight_scheme = 'sqrt', TOP_K = 30, verbose = True, this_is_word = False, expand = False):
    color1 = 'black'
    color2 = 'blue'
    color3 = 'red'

    # 일단은 centrality top VC 를 그려보자
    central = pickle.load(open(util_folder + 'investor_centrality_between_one_over_k.pickle'))
    topVC = [uuid for uuid, value in central[:TOP_K]]
    top_funding_round_uuids = df_investments[df_investments['investor_uuid'].isin(topVC)]['funding_round_uuid'].unique()
    
    if this_is_word:
        expert = pickle.load(open('../data/others/investor_sqrt_harmonic_rank_for_all.pickle'.format(category)))
    else:
#         expert = pickle.load(open('../data/others/investor_harmonic_rank_for_{}.pickle'.format(category)))
        expert = pickle.load(open('../data/others/investor_{}_harmonic_rank_for_{}.pickle'.format(weight_scheme, category)))
    expert = sorted(expert.items(), key = operator.itemgetter(1))

    expertVC = [uuid for uuid, value in expert[:TOP_K]]
    expert_funding_round_uuids = df_investments[df_investments['investor_uuid'].isin(expertVC)]['funding_round_uuid'].unique()

    if this_is_word:
        if 'word2company' not in globals():
            print('loading word2company')
            global word2company
            word2company = pickle.load(open(util_folder + 'word2company.pickle'))
        if 'model' not in globals():
            print('loading word2vec model')
            global model
            model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')

        words = category
        final_words = []
        if type(words) == str:
            words = [words]
        for word in words:
            if ' ' in word:
                word = word.replace(' ', '_')
            if expand:
                if word not in model: continue
                _words = model.most_similar(word)
                _words = [str(_word) for _word, sim in _words]
                final_words.extend(_words)
            final_words.append(word)
        final_words = list(set(final_words))
        print final_words

        # 해당 단어가 있는 회사들을 모은다
        companies = []
        for word in final_words:
            _companies = word2company.get(word, [])
            companies.extend(_companies)
        companies = list(set(companies))

#         if category not in word2company:
#             print 'word', category, 'is not in dataset'
#             return
        df = df_funding[df_funding['company_uuid'].isin(companies)].drop_duplicates('funding_round_uuid')    
    else:
        df = df_funding[df_funding['category'] == category].drop_duplicates('funding_round_uuid')
    df_top = df[df['funding_round_uuid'].isin(top_funding_round_uuids)]
    df_expert = df[df['funding_round_uuid'].isin(expert_funding_round_uuids)]

    print "Category:",category
    print '# investment by all VC', df.shape[0]
    print '# investment by top VC', df_top.shape[0]
    print '# investment by expert VC', df_expert.shape[0]
    if verbose:
        for vc in expertVC[:TOP_K]:
            print df_investors[df_investors['uuid'] == (vc)]['investor_name'].values[0]
    try:
        start_year = min(df['year-month'].values)[:4]
    except Exception as e:
        print 'no data'
        return
    count = df.groupby('year-month')['investor_uuid'].apply(lambda x: len(x)).rename('count').reset_index()
    count_top = df_top.groupby('year-month')['investor_uuid'].apply(lambda x: len(x)).rename('count_top').reset_index()
    count_expert = df_expert.groupby('year-month')['investor_uuid'].apply(lambda x: len(x)).rename('count_expert').reset_index()
    for year in range(int(start_year), 2018):
        year = str(year)
        if count[count['year-month'] == '{}-01'.format(year)].shape[0] == 0:
            count.loc[-1] = ['{}-01'.format(year), 0]
            count.index = count.index + 1
    count['year'] = np.where(True, count['year-month'].str[:4], '')
    count = count.merge(count_top, on = 'year-month', how = 'left')
    count = count.merge(count_expert, on = 'year-month', how = 'left')

    count = count.sort_values('year-month')
    count = count.fillna(0)

    count['cum_count'] = count['count'].cumsum()
    count['cum_count'] = count['cum_count'] / max(count['cum_count'])

    count['cum_count_top'] = count['count_top'].cumsum()
    count['cum_count_top'] = count['cum_count_top'] / max(count['cum_count_top'])

    count['cum_count_expert'] = count['count_expert'].cumsum()
    count['cum_count_expert'] = count['cum_count_expert'] / max(count['cum_count_expert'])
    
    count[['year-month', 'cum_count', 'cum_count_top', 'cum_count_expert']].plot(x = count['year'], linestyle = '-', color = [color1, color2, color3], fontsize = 25, figsize = (30, 8)).legend(loc = 2, fontsize = 20, labels = ['total', 'centrality', 'early'])
    plt.show()

# %%
for category in df_category_count['category'].head(3).values:
    plot_early_investors(category = category, weight_scheme = 'log', TOP_K = 10, verbose = False)
# Out:
# Category: software
# # investment by all VC 15892
# # investment by top VC 1405
# # investment by expert VC 1273
# Category: mobile
# # investment by all VC 12275
# # investment by top VC 1329
# # investment by expert VC 949
# Category: health care
# # investment by all VC 10972
# # investment by top VC 690
# # investment by expert VC 589

# %%
word_list = ['deep_learning', 'fintech', 'drone', 'wearable', '3d printing', 'virtual reality']
for word in word_list:
    plot_early_investors(category = word, weight_scheme = 'log', TOP_K = 30, verbose = False, this_is_word = True, expand = False)
    plot_early_investors(category = word, weight_scheme = 'log', TOP_K = 30, verbose = False, this_is_word = True, expand = True)
# Out:
# ['deep_learning']
# Category: deep_learning
# # investment by all VC 196
# # investment by top VC 33
# # investment by expert VC 13
# ['neural_network', 'computer_vision', 'big_data', 'ai', 'reinforcement_learning', 'cognitive_computing', 'pattern_recognition', 'neural_networks', 'machine_learning', 'artificial_intelligence', 'deep_learning']
# Category: deep_learning
# # investment by all VC 4162
# # investment by top VC 698
# # investment by expert VC 527
# ['fintech']
# Category: fintech
# # investment by all VC 268
# # investment by top VC 37
# # investment by expert VC 8
# ['agtech', 'fintech', 'regtech', 'insurtech', 'edtech', 'cleantech', 'tech', 'fin_tech', 'ad_tech', 'healthtech', 'adtech']
# Category: fintech
# # investment by all VC 1904
# # investment by top VC 257
# # investment by expert VC 134
# ['drone']
# Category: drone
# # investment by all VC 180
# # investment by top VC 31
# # investment by expert VC 14
# ['remotely_operated', 'drone', 'uas', 'unmanned_aerial', 'uav', 'unmanned', 'uavs', 'drones', 'unmanned_aircraft', 'vtol', 'fixed_wing']
# Category: drone
# # investment by all VC 363
# # investment by top VC 63
# # investment by expert VC 43
# ['wearable']
# Category: wearable
# # investment by all VC 337
# # investment by top VC 23
# # investment by expert VC 16
# ['wearables', 'smartwatch', 'smart_glasses', 'wearable_device', 'wearable', 'wrist_worn', 'bluetooth_smart', 'wearable_devices', 'sensor', 'wearable_tech', 'wearable_technology']
# Category: wearable
# # investment by all VC 1473
# # investment by top VC 171
# # investment by expert VC 142
# ['3d_printing']
# Category: 3d printing
# # investment by all VC 0
# # investment by top VC 0
# # investment by expert VC 0
# no data
# []
# Category: 3d printing
# # investment by all VC 0
# # investment by top VC 0
# # investment by expert VC 0
# no data
# ['virtual_reality']
# Category: virtual reality
# # investment by all VC 310
# # investment by top VC 53
# # investment by expert VC 33
# ['ar_vr', 'htc_vive', 'virtual_reality', 'cinematic_vr', 'augmented_reality', 'vr_ar', 'vr', 'ar', 'immersive', 'oculus_rift', 'mixed_reality']
# Category: virtual reality
# # investment by all VC 981
# # investment by top VC 160
# # investment by expert VC 98

# %%
save = False
begin_from = 1000 # 처음부터 학습하고 싶으면 0 으로 설정

if save:
    category_weight = df_category_count.set_index('category')['count'].to_dict()
    category2investor = pickle.load(open('../data/others/category2investor.pickle'))

    weight_schemes = ['log', 'sqrt', 'simple']
    for weight_scheme in weight_schemes:
        for index, _category in enumerate(df_category_count['category']):
            if index < begin_from: continue
            score = {}
            for category, investors in category2investor.items():
                if category == _category: continue
                for investor in investors:
                    score[investor] = 0
            all_investors = score.keys()
            num_max = len(all_investors)

            print 'target category', _category, index, len(category2investor.keys())
            weight_sum = 0
            for category, investors in category2investor.items():
                if category == _category: continue
                if weight_scheme == 'simple': weight_sum += 1
                if weight_scheme == 'sqrt': weight_sum += np.sqrt(category_weight[category])
                if weight_scheme == 'log': weight_sum += np.log(category_weight[category])

                default_rank = (num_max + len(investors)) / 2.0
                default_rank = 1.0 / default_rank

                for rank, investor in enumerate(investors):
                    rank = 1.0 / (rank + 1)
                    if weight_scheme == 'simple': score[investor] += rank
                    if weight_scheme == 'sqrt': score[investor] += (np.sqrt(category_weight[category]) * rank)
                    if weight_scheme == 'log': score[investor] += (np.log(category_weight[category]) * rank)

                for investor in all_investors:
                    if investor not in investors:
                        if weight_scheme == 'simple': score[investor] += default_rank
                        if weight_scheme == 'sqrt': score[investor] += (np.sqrt(category_weight[category]) * default_rank)
                        if weight_scheme == 'log': score[investor] += (np.log(category_weight[category]) * default_rank)

            for investor in all_investors:
                score[investor] = weight_sum / score[investor]

            try:
                with open('../data/others/investor_{}_harmonic_rank_for_{}.pickle'.format(weight_scheme, _category), 'w') as f:
                    pickle.dump(score, f)
            except Exception as e:
                print e
# Out:
# target category software 0 651
# target category mobile 1 651
# target category health care 2 651
# target category enterprise software 3 651
# target category e-commerce 4 651
# target category internet 5 651
# target category biotechnology 6 651
# target category information technology 7 651
# target category saas 8 651
# target category analytics 9 651
# target category advertising 10 651
# target category manufacturing 11 651
# target category medical 12 651
# target category apps 13 651
# target category social media 14 651
# target category education 15 651
# target category finance 16 651
# target category big data 17 651
# target category fintech 18 651
# target category hardware 19 651
# target category financial services 20 651
# target category medical device 21 651
# target category security 22 651
# target category cloud computing 23 651
# target category video 24 651
# target category retail 25 651
# target category telecommunications 26 651
# target category wireless 27 651
# target category travel 28 651
# target category pharmaceutical 29 651
# target category service industry 30 651
# target category fashion 31 651
# target category electronics 32 651
# target category marketing 33 651
# target category marketplace 34 651
# target category therapeutics 35 651
# target category digital media 36 651
# target category energy 37 651
# target category health diagnostics 38 651
# target category internet of things 39 651
# target category mobile apps 40 651
# target category real estate 41 651
# target category search engine 42 651
# target category semiconductor 43 651
# target category automotive 44 651
# target category machine learning 45 651
# target category content 46 651
# target category information services 47 651
# target category artificial intelligence 48 651
# target category messaging 49 651
# target category consumer electronics 50 651
# target category music 51 651
# target category payments 52 651
# target category b2b 53 651
# target category shopping 54 651
# target category web hosting 55 651
# target category gaming 56 651
# target category transportation 57 651
# target category ios 58 651
# target category sports 59 651
# target category real time 60 651
# target category computer 61 651
# target category publishing 62 651
# target category business intelligence 63 651
# target category collaboration 64 651
# target category logistics 65 651
# target category consulting 66 651
# target category developer tools 67 651
# target category hospitality 68 651
# target category cyber security 69 651
# target category edtech 70 651
# target category renewable energy 71 651
# target category customer service 72 651
# target category media and entertainment 73 651
# target category news 74 651
# target category online portals 75 651
# target category web development 76 651
# target category recruiting 77 651
# target category lifestyle 78 651
# target category crm 79 651
# target category food and beverage 80 651
# target category android 81 651
# target category robotics 82 651
# target category events 83 651
# target category fitness 84 651
# target category human resources 85 651
# target category network security 86 651
# target category social network 87 651
# target category developer platform 88 651
# target category consumer 89 651
# target category photography 90 651
# target category genetics 91 651
# target category restaurants 92 651
# target category solar 93 651
# target category product design 94 651
# target category marketing automation 95 651
# target category video streaming 96 651
# target category location based services 97 651
# target category infrastructure 98 651
# target category small and medium businesses 99 651
# target category brand marketing 100 651
# target category advertising platforms 101 651
# target category industrial 102 651
# target category biopharma 103 651
# target category communities 104 651
# target category predictive analytics 105 651
# target category cloud data services 106 651
# target category wearables 107 651
# target category video games 108 651
# target category wellness 109 651
# target category local 110 651
# target category business development 111 651
# target category energy efficiency 112 651
# target category mobile payments 113 651
# target category e-learning 114 651
# target category communications infrastructure 115 651
# target category banking 116 651
# target category digital entertainment 117 651
# target category delivery 118 651
# target category oil and gas 119 651
# target category market research 120 651
# target category tourism 121 651
# target category training 122 651
# target category life science 123 651
# target category crowdsourcing 124 651
# target category 3d technology 125 651
# target category social media marketing 126 651
# target category developer apis 127 651
# target category open source 128 651
# target category clean energy 129 651
# target category supply chain management 130 651
# target category hospital 131 651
# target category insurance 132 651
# target category virtualization 133 651
# target category agriculture 134 651
# target category retail technology 135 651
# target category cleantech 136 651
# target category mhealth 137 651
# target category food processing 138 651
# target category email 139 651
# target category data visualization 140 651
# target category database 141 651
# target category risk management 142 651
# target category construction 143 651
# target category non profit 144 651
# target category legal 145 651
# target category virtual reality 146 651
# target category nanotechnology 147 651
# target category beauty 148 651
# target category sensor 149 651
# target category innovation management 150 651
# target category social 151 651
# target category mobile devices 152 651
# target category voip 153 651
# target category audio 154 651
# target category professional services 155 651
# target category identity management 156 651
# target category personalization 157 651
# target category crowdfunding 158 651
# target category data integration 159 651
# target category energy management 160 651
# target category aerospace 161 651
# target category broadcasting 162 651
# target category chemical 163 651
# target category cloud infrastructure 164 651
# target category personal finance 165 651
# target category mobile advertising 166 651
# target category web browsers 167 651
# target category data center 168 651
# target category photo sharing 169 651
# target category file sharing 170 651
# target category venture capital 171 651
# target category ticketing 172 651
# target category augmented reality 173 651
# target category online games 174 651
# target category art 175 651
# target category project management 176 651
# target category employment 177 651
# target category public transportation 178 651
# target category accounting 179 651
# target category enterprise 180 651
# target category e-commerce platforms 181 651
# target category water 182 651
# target category bitcoin 183 651
# target category web design 184 651
# target category clinical trials 185 651
# target category digital marketing 186 651
# target category loyalty programs 187 651
# target category outsourcing 188 651
# target category navigation 189 651
# target category career planning 190 651
# target category network hardware 191 651
# target category public relations 192 651
# target category leisure 193 651
# target category sales 194 651
# target category event management 195 651
# target category email marketing 196 651
# target category personal health 197 651
# target category optical communication 198 651
# target category credit 199 651
# target category paas 200 651
# target category seo 201 651
# target category document management 202 651
# target category ad network 203 651
# target category lead generation 204 651
# target category 3d printing 205 651
# target category commercial real estate 206 651
# target category property management 207 651
# target category sustainability 208 651
# target category data storage 209 651
# target category children 210 651
# target category tv 211 651
# target category home automation 212 651
# target category subscription service 213 651
# target category drones 214 651
# target category gamification 215 651
# target category cloud management 216 651
# target category lighting 217 651
# target category food delivery 218 651
# target category language learning 219 651
# target category computer vision 220 651
# target category energy storage 221 651
# target category management information systems 222 651
# target category blogging platforms 223 651
# target category test and measurement 224 651
# target category home decor 225 651
# target category coupons 226 651
# target category film 227 651
# target category advanced materials 228 651
# target category printing 229 651
# target category collaborative consumption 230 651
# target category wine and spirits 231 651
# target category lending 232 651
# target category social media management 233 651
# target category universities 234 651
# target category natural language processing 235 651
# target category content delivery network 236 651
# target category sales automation 237 651
# target category ad targeting 238 651
# target category farming 239 651
# target category peer to peer 240 651
# target category application performance management 241 651
# target category online auctions 242 651
# target category natural resources 243 651
# target category women's 244 651
# target category knowledge management 245 651
# target category enterprise applications 246 651
# target category government 247 651
# target category web apps 248 651
# target category trading platform 249 651
# target category govtech 250 651
# target category organic food 251 651
# target category furniture 252 651
# target category cloud security 253 651
# target category recycling 254 651
# target category shipping 255 651
# target category point of sale 256 651
# target category image recognition 257 651
# target category price comparison 258 651
# target category jewelry 259 651
# target category data mining 260 651
# target category app marketing 261 651
# target category nutrition 262 651
# target category industrial automation 263 651
# target category parenting 264 651
# target category intellectual property 265 651
# target category isp 266 651
# target category professional networking 267 651
# target category rental 268 651
# target category billing 269 651
# target category consumer goods 270 651
# target category environmental engineering 271 651
# target category private social networking 272 651
# target category architecture 273 651
# target category tutoring 274 651
# target category waste management 275 651
# target category greentech 276 651
# target category gift card 277 651
# target category electric vehicle 278 651
# target category wealth management 279 651
# target category auctions 280 651
# target category pet 281 651
# target category higher education 282 651
# target category fraud detection 283 651
# target category cooking 284 651
# target category video on demand 285 651
# target category sms 286 651
# target category compliance 287 651
# target category ediscovery 288 651
# target category it management 289 651
# target category content creators 290 651
# target category it infrastructure 291 651
# target category privacy 292 651
# target category management consulting 293 651
# target category flash storage 294 651
# target category smart building 295 651
# target category fuel 296 651
# target category communication hardware 297 651
# target category pc games 298 651
# target category cosmetics 299 651
# target category autonomous vehicles 300 651
# target category iaas 301 651
# target category digital signage 302 651
# target category neuroscience 303 651
# target category rfid 304 651
# target category public safety 305 651
# target category battery 306 651
# target category advice 307 651
# target category content discovery 308 651
# target category home renovation 309 651
# target category incubators 310 651
# target category credit cards 311 651
# target category ebooks 312 651
# target category semantic search 313 651
# target category biometrics 314 651
# target category consumer lending 315 651
# target category embedded systems 316 651
# target category interior design 317 651
# target category geospatial 318 651
# target category water purification 319 651
# target category content marketing 320 651
# target category impact investing 321 651
# target category sporting goods 322 651
# target category toys 323 651
# target category electrical distribution 324 651
# target category dating 325 651
# target category classifieds 326 651
# target category sharing economy 327 651
# target category national security 328 651
# target category shoes 329 651
# target category video conferencing 330 651
# target category casual games 331 651
# target category task management 332 651
# target category reservations 333 651
# target category grocery 334 651
# target category hotel 335 651
# target category commercial 336 651
# target category car sharing 337 651
# target category diabetes 338 651
# target category corporate training 339 651
# target category text analytics 340 651
# target category real estate investment 341 651
# target category reputation 342 651
# target category video chat 343 651
# target category asset management 344 651
# target category dental 345 651
# target category wholesale 346 651
# target category skill assessment 347 651
# target category technical support 348 651
# target category biofuel 349 651
# target category child care 350 651
# target category parking 351 651
# target category productivity tools 352 651
# target category charity 353 651
# target category wind energy 354 651
# target category intelligent systems 355 651
# target category transaction processing 356 651
# target category mechanical engineering 357 651
# target category graphic design 358 651
# target category stock exchanges 359 651
# target category business information systems 360 651
# target category wedding 361 651
# target category eyewear 362 651
# target category ride sharing 363 651
# target category meeting software 364 651
# target category social entrepreneurship 365 651
# target category air transportation 366 651
# target category delivery service 367 651
# target category social crm 368 651
# target category home services 369 651
# target category journalism 370 651
# target category consumer software 371 651
# target category cloud storage 372 651
# target category speech recognition 373 651
# target category procurement 374 651
# target category contact management 375 651
# target category concerts 376 651
# target category staffing agency 377 651
# target category power grid 378 651
# target category guides 379 651
# target category outdoors 380 651
# target category building material 381 651
# target category social recruiting 382 651
# target category music streaming 383 651
# target category mapping services 384 651
# target category bioinformatics 385 651
# target category erp 386 651
# target category fleet management 387 651
# target category adventure travel 388 651
# target category industrial engineering 389 651
# target category direct marketing 390 651
# target category social media advertising 391 651
# target category freelance 392 651
# target category product search 393 651
# target category employee benefits 394 651
# target category software engineering 395 651
# target category coffee 396 651
# target category lead management 397 651
# target category gambling 398 651
# target category internet radio 399 651
# target category human computer interaction 400 651
# target category local business 401 651
# target category fantasy sports 402 651
# target category dsp 403 651
# target category coworking 404 651
# target category product research 405 651
# target category visual search 406 651
# target category semantic web 407 651
# target category law enforcement 408 651
# target category scheduling 409 651
# target category esports 410 651
# target category politics 411 651
# target category b2c 412 651
# target category elder care 413 651
# target category film production 414 651
# target category family 415 651
# target category financial exchanges 416 651
# target category organic 417 651
# target category emerging markets 418 651
# target category health insurance 419 651
# target category rental property 420 651
# target category browser extensions 421 651
# target category craft beer 422 651
# target category content syndication 423 651
# target category photo editing 424 651
# target category home improvement 425 651
# target category nfc 426 651
# target category presentations 427 651
# target category animation 428 651
# target category data center automation 429 651
# target category auto insurance 430 651
# target category mmo games 431 651
# target category diy 432 651
# target category cad 433 651
# target category textiles 434 651
# target category satellite communication 435 651
# target category social bookmarking 436 651
# target category social news 437 651
# target category laser 438 651
# target category tv production 439 651
# target category baby 440 651
# target category consumer reviews 441 651
# target category local advertising 442 651
# target category virtual currency 443 651
# target category gift 444 651
# target category dietary supplements 445 651
# target category video editing 446 651
# target category video advertising 447 651
# target category mining technology 448 651
# target category private cloud 449 651
# target category green consumer goods 450 651
# target category psychology 451 651
# target category direct sales 452 651
# target category nightlife 453 651
# target category simulation 454 651
# target category celebrity 455 651
# target category same day delivery 456 651
# target category linux 457 651
# target category alternative medicine 458 651
# target category green building 459 651
# target category biomass energy 460 651
# target category brewing 461 651
# target category social innovation 462 651
# target category facebook 463 651
# target category gps 464 651
# target category veterinary 465 651
# target category q&a 466 651
# target category handmade 467 651
# target category industrial manufacturing 468 651
# target category ict 469 651
# target category travel accommodations 470 651
# target category angel investment 471 651
# target category creative agency 472 651
# target category eda 473 651
# target category product management 474 651
# target category environmental consulting 475 651
# target category hedge funds 476 651
# target category homeland security 477 651
# target category agtech 478 651
# target category men's 479 651
# target category travel agency 480 651
# target category self-storage 481 651
# target category virtual desktop 482 651
# target category college recruiting 483 651
# target category indoor positioning 484 651
# target category packaging services 485 651
# target category unified communications 486 651
# target category group buying 487 651
# target category space travel 488 651
# target category reading apps 489 651
# target category sem 490 651
# target category freemium 491 651
# target category young adults 492 651
# target category mineral 493 651
# target category quantified self 494 651
# target category virtual assistant 495 651
# target category qr codes 496 651
# target category soccer 497 651
# target category alumni 498 651
# target category a/b testing 499 651
# [Errno 2] No such file or directory: '../data/others/investor_log_harmonic_rank_for_a/b testing.pickle'
# target category recreation 500 651
# target category music venues 501 651
# target category home health care 502 651
# target category facial recognition 503 651
# target category call center 504 651
# target category app discovery 505 651
# target category tea 506 651
# target category translation service 507 651
# target category machinery manufacturing 508 651
# target category animal feed 509 651
# target category taxi service 510 651
# target category collectibles 511 651
# target category elderly 512 651
# target category physical security 513 651
# target category operating systems 514 651
# target category sponsorship 515 651
# target category property development 516 651
# target category edutainment 517 651
# target category chemical engineering 518 651
# target category embedded software 519 651
# target category virtual world 520 651
# target category cryptocurrency 521 651
# target category social shopping 522 651
# target category consumer applications 523 651
# target category home and garden 524 651
# target category online forums 525 651
# target category residential 526 651
# target category precious metals 527 651
# target category mining 528 651
# target category housekeeping service 529 651
# target category lingerie 530 651
# target category nightclubs 531 651
# target category plastics and rubber manufacturing 532 651
# target category film distribution 533 651
# target category mooc 534 651
# target category ad server 535 651
# target category leasing 536 651
# target category theatre 537 651
# target category office administration 538 651
# target category musical instruments 539 651
# target category fuel cell 540 651
# target category ux design 541 651
# target category independent music 542 651
# target category humanitarian 543 651
# target category fmcg 544 651
# target category flowers 545 651
# target category cycling 546 651
# target category virtual workforce 547 651
# target category laundry and dry-cleaning 548 651
# target category ad retargeting 549 651
# target category primary education 550 651
# target category vertical search 551 651
# target category business travel 552 651
# target category consumer research 553 651
# target category teenagers 554 651
# target category motion capture 555 651
# target category comics 556 651
# target category virtual goods 557 651
# target category vacation rental 558 651
# target category stem education 559 651
# target category micro lending 560 651
# target category outdoor advertising 561 651
# target category hydroponics 562 651
# target category personal branding 563 651
# target category charter schools 564 651
# target category debit cards 565 651
# target category music education 566 651
# target category resorts 567 651
# target category nutraceutical 568 651
# target category cosmetic surgery 569 651
# target category quality assurance 570 651
# target category snack food 571 651
# target category racing 572 651
# target category courier service 573 651
# target category fruit 574 651
# target category drone management 575 651
# target category emergency medicine 576 651
# target category freight service 577 651
# target category facility management 578 651
# target category assisted living 579 651
# target category sns 580 651
# target category religion 581 651
# target category fertility 582 651
# target category millennials 583 651
# target category ehr 584 651
# target category farmers market 585 651
# target category boating 586 651
# target category life insurance 587 651
# target category aquaculture 588 651
# target category affiliate marketing 589 651
# target category mothers 590 651
# target category lgbt 591 651
# target category podcast 592 651
# target category performing arts 593 651
# target category google glass 594 651
# target category recipes 595 651
# target category building maintenance 596 651
# target category assistive technology 597 651
# target category marijuana 598 651
# target category bakery 599 651
# target category secondary education 600 651
# target category commercial lending 601 651
# target category warehousing 602 651
# target category civil engineering 603 651
# target category in-flight entertainment 604 651
# target category property insurance 605 651
# target category event promotion 606 651
# target category ad exchange 607 651
# target category drm 608 651
# target category personal development 609 651
# target category rehabilitation 610 651
# target category gpu 611 651
# target category casino 612 651
# target category catering 613 651
# target category fossil fuels 614 651
# target category funerals 615 651
# target category field support 616 651
# target category mechanical design 617 651
# target category underserved children 618 651
# target category retirement 619 651
# target category winery 620 651
# target category gift exchange 621 651
# target category intrusion detection 622 651
# target category marine transportation 623 651
# target category landscaping 624 651
# target category cause marketing 625 651
# target category usability testing 626 651
# target category golf 627 651
# target category continuing education 628 651
# target category document preparation 629 651
# target category cms 630 651
# target category fpga 631 651
# target category e-signature 632 651
# target category sex tech 633 651
# target category livestock 634 651
# target category textbook 635 651
# target category railroad 636 651
# target category adult 637 651
# target category domain registrar 638 651
# target category nursing and residential care 639 651
# target category diving 640 651
# target category wired telecommunications 641 651
# target category homeless shelter 642 651
# target category local shopping 643 651
# target category tobacco 644 651
# target category recreational vehicles 645 651
# target category audiobooks 646 651
# target category seafood 647 651
# target category wood processing 648 651
# target category franchise 649 651
# target category spam filtering 650 651
# target category swimming 651 651
# target category playstation 652 651
# target category facilities support services 653 651
# target category serious games 654 651
# target category vending and concessions 655 651
# target category shipping broker 656 651
# target category asic 657 651
# target category gift registry 658 651
# target category sex industry 659 651
# target category credit bureau 660 651
# target category sailing 661 651
# target category american football 662 651
# target category nuclear 663 651
# target category hunting 664 651
# target category archiving service 665 651
# target category commercial insurance 666 651
# target category museums and historical sites 667 651
# target category debt collections 668 651
# target category music label 669 651
# target category janitorial service 670 651
# target category google 671 651
# target category food trucks 672 651
# target category webos 673 651
# target category console games 674 651
# target category confectionery 675 651
# target category basketball 676 651
# target category tour operator 677 651
# target category made to order 678 651
# target category multi-level marketing 679 651
# target category paper manufacturing 680 651
# target category shopping mall 681 651
# target category industrial design 682 651
# target category prediction markets 683 651
# target category tennis 684 651
# target category skiing 685 651
# target category forestry 686 651
# target category timeshare 687 651
# target category contests 688 651
# target category social assistance 689 651
# target category windows phone 690 651
# target category windows 691 651
# target category distillery 692 651
# target category water transportation 693 651
# target category foundries 694 651
# target category civictech 695 651
# target category generation z 696 651
# target category outpatient care 697 651
# target category twitter 698 651
# target category macos 699 651
# target category timber 700 651
# target category presentation software 701 651
# target category pollution control 702 651
# target category corrections facilities 703 651
# target category limousine service 704 651
# target category trade shows 705 651
# target category first aid 706 651
# target category desktop apps 707 651
# target category vocational education 708 651
# target category amusement park and arcade 709 651
# target category flash sale 710 651
# target category horticulture 711 651
# target category penetration testing 712 651

# %%
# 단어가 주어졌을때 연관 단어를 배출하는 helper function
def related_words(words):
    if 'model' not in globals():
        print('loading word2vec model')
        global model
        model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')
        
    final_words = []
    if type(words) == str:
        words = [words]
    for word in words:
        if ' ' in word:
            word = word.replace(' ', '_')
        if word not in model: continue
        _words = model.most_similar(word)
        _words = [str(_word) for _word, sim in _words if _word not in words]
        final_words.extend(_words)
        final_words.append(word)
    final_words = list(set(final_words))
    print final_words
    return final_words

# %%
# 모든 카테고리에 대해서 빠른 회사들 찾아서 저장
# 모든 단어에 대해서 빠른 회사들 찾아서 저장
category_min = 10
word_min = 10
save_category = False
save_word = False

if save_category:
    df_category_count = pd.read_csv('../data/others/category_count.csv')
    category2investor = {}
    investor2category = {}

    df_category_count = df_category_count[df_category_count['count'] >= category_min]
    categories = df_category_count['category'].values
    for index, category in enumerate(categories):
        if index % (len(categories) // 10) == 0:
            print index, len(categories)
        if type(category) != str: continue
        score = get_early_investors_by_categories(category, early_investment_percent = 10, top_k = 30, verbose = False)

        investors = score['investor_uuid'].values
        category2investor[category] = investors
        for investor in investors:
            if investor not in investor2category:
                investor2category[investor] = []
            investor2category[investor].append(category)
    with open('../data/others/category2investor.pickle', 'w') as f:
        pickle.dump(category2investor, f)
    with open('../data/others/investor2category.pickle', 'w') as f:
        pickle.dump(investor2category, f)

    for category, investors in category2investor.items():
        print category
        print investors
        break
    
if save_word:
    # load required dataset
    if 'word2company' not in globals():
        print('loading word2company')
        global word2company
        word2company = pickle.load(open(util_folder + 'word2company.pickle'))
    if 'company2word' not in globals():
        print('loading company2word')
        global company2word
        company2word = pickle.load(open(util_folder + 'company2word.pickle'))

    word2investor = {}
    investor2word = {}

    words = word2company.keys()
    for index, word in enumerate(words):
        if index % (len(words) // 100) == 0:
            print index, len(words)
        if len(word2company[word]) < word_min: continue            
            
        score = get_early_investors_by_words([word], early_investment_percent = 10, top_k = 30, verbose = False)
        if score is None: continue
        investors = score['investor_uuid'].values
        word2investor[word] = investors
        for investor in investors:
            if investor not in investor2word:
                investor2word[investor] = []
            investor2word[investor].append(word)
    with open('../data/others/word2investor.pickle', 'w') as f:
        pickle.dump(word2investor, f)
    with open('../data/others/investor2word.pickle', 'w') as f:
        pickle.dump(investor2word, f)

    for word, investors in word2investor.items():
        print word
        print investors
        break
# Out:
# 0 651
# (15892, 6)
# (12275, 6)
# (10972, 6)
# (9600, 6)
# (9173, 6)
# (8314, 6)
# (7931, 6)
# (6659, 6)
# (6240, 6)
# (5959, 6)
# (4872, 6)
# (4829, 6)
# (4767, 6)
# (4493, 6)
# (4357, 6)
# (3717, 6)
# (3650, 6)
# (3482, 6)
# (3348, 6)
# (3257, 6)
# (3200, 6)
# (3113, 6)
# (2877, 6)
# (2782, 6)
# (2703, 6)
# (2509, 6)
# (2406, 6)
# (2317, 6)
# (2249, 6)
# (2217, 6)
# (2183, 6)
# (2102, 6)
# (2079, 6)
# (2010, 6)
# (2002, 6)
# (2001, 6)
# (1984, 6)
# (1973, 6)
# (1902, 6)
# (1874, 6)
# (1703, 6)
# (1681, 6)
# (1656, 6)
# (1624, 6)
# (1611, 6)
# (1592, 6)
# (1572, 6)
# (1547, 6)
# (1542, 6)
# (1526, 6)
# (1502, 6)
# (1493, 6)
# (1492, 6)
# (1491, 6)
# (1470, 6)
# (1449, 6)
# (1418, 6)
# (1367, 6)
# (1347, 6)
# (1323, 6)
# (1285, 6)
# (1258, 6)
# (1255, 6)
# (1223, 6)
# (1205, 6)
# 65 651
# (1195, 6)
# (1166, 6)
# (1163, 6)
# (1146, 6)
# (1144, 6)
# (1135, 6)
# (1118, 6)
# (1102, 6)
# (1102, 6)
# (1099, 6)
# (1098, 6)
# (1080, 6)
# (1068, 6)
# (1062, 6)
# (1048, 6)
# (1040, 6)
# (1031, 6)
# (1018, 6)
# (1011, 6)
# (1010, 6)
# (1003, 6)
# (1001, 6)
# (954, 6)
# (904, 6)
# (900, 6)
# (891, 6)
# (883, 6)
# (878, 6)
# (871, 6)
# (868, 6)
# (867, 6)
# (845, 6)
# (838, 6)
# (835, 6)
# (827, 6)
# (824, 6)
# (823, 6)
# (799, 6)
# (797, 6)
# (796, 6)
# (793, 6)
# (769, 6)
# (744, 6)
# (729, 6)
# (721, 6)
# (710, 6)
# (703, 6)
# (703, 6)
# (701, 6)
# (700, 6)
# (692, 6)
# (677, 6)
# (675, 6)
# (670, 6)
# (669, 6)
# (664, 6)
# (657, 6)
# (643, 6)
# (643, 6)
# (641, 6)
# (637, 6)
# (630, 6)
# (625, 6)
# (623, 6)
# (619, 6)
# 130 651
# (613, 6)
# (612, 6)
# (610, 6)
# (596, 6)
# (592, 6)
# (587, 6)
# (583, 6)
# (577, 6)
# (556, 6)
# (551, 6)
# (551, 6)
# (546, 6)
# (522, 6)
# (519, 6)
# (518, 6)
# (515, 6)
# (500, 6)
# (498, 6)
# (496, 6)
# (491, 6)
# (486, 6)
# (477, 6)
# (459, 6)
# (458, 6)
# (458, 6)
# (456, 6)
# (436, 6)
# (434, 6)
# (431, 6)
# (430, 6)
# (428, 6)
# (427, 6)
# (424, 6)
# (421, 6)
# (420, 6)
# (418, 6)
# (417, 6)
# (414, 6)
# (413, 6)
# (413, 6)
# (408, 6)
# (399, 6)
# (393, 6)
# (391, 6)
# (390, 6)
# (387, 6)
# (380, 6)
# (379, 6)
# (377, 6)
# (376, 6)
# (374, 6)
# (374, 6)
# (371, 6)
# (365, 6)
# (362, 6)
# (361, 6)
# (358, 6)
# (347, 6)
# (345, 6)
# (343, 6)
# (342, 6)
# (337, 6)
# (335, 6)
# (334, 6)
# (333, 6)
# 195 651
# (327, 6)
# (327, 6)
# (320, 6)
# (320, 6)
# (318, 6)
# (317, 6)
# (315, 6)
# (313, 6)
# (313, 6)
# (313, 6)
# (312, 6)
# (311, 6)
# (307, 6)
# (304, 6)
# (304, 6)
# (304, 6)
# (299, 6)
# (299, 6)
# (298, 6)
# (297, 6)
# (297, 6)
# (292, 6)
# (291, 6)
# (291, 6)
# (290, 6)
# (290, 6)
# (283, 6)
# (283, 6)
# (272, 6)
# (267, 6)
# (265, 6)
# (263, 6)
# (263, 6)
# (259, 6)
# (256, 6)
# (254, 6)
# (254, 6)
# (253, 6)
# (253, 6)
# (253, 6)
# (251, 6)
# (251, 6)
# (250, 6)
# (249, 6)
# (248, 6)
# (248, 6)
# (248, 6)
# (245, 6)
# (244, 6)
# (242, 6)
# (242, 6)
# (242, 6)
# (239, 6)
# (237, 6)
# (236, 6)
# (236, 6)
# (236, 6)
# (234, 6)
# (234, 6)
# (233, 6)
# (233, 6)
# (232, 6)
# (226, 6)
# (225, 6)
# (223, 6)
# 260 651
# (223, 6)
# (223, 6)
# (218, 6)
# (217, 6)
# (217, 6)
# (216, 6)
# (216, 6)
# (215, 6)
# (215, 6)
# (214, 6)
# (210, 6)
# (208, 6)
# (206, 6)
# (206, 6)
# (205, 6)
# (205, 6)
# (201, 6)
# (200, 6)
# (199, 6)
# (198, 6)
# (195, 6)
# (191, 6)
# (184, 6)
# (184, 6)
# (182, 6)
# (182, 6)
# (181, 6)
# (180, 6)
# (179, 6)
# (179, 6)
# (176, 6)
# (175, 6)
# (175, 6)
# (174, 6)
# (174, 6)
# (174, 6)
# (172, 6)
# (172, 6)
# (172, 6)
# (171, 6)
# (171, 6)
# (170, 6)
# (169, 6)
# (168, 6)
# (168, 6)
# (168, 6)
# (165, 6)
# (164, 6)
# (163, 6)
# (161, 6)
# (161, 6)
# (155, 6)
# (155, 6)
# (154, 6)
# (152, 6)
# (149, 6)
# (149, 6)
# (148, 6)
# (148, 6)
# (148, 6)
# (146, 6)
# (146, 6)
# (146, 6)
# (144, 6)
# (143, 6)
# 325 651
# (143, 6)
# (141, 6)
# (140, 6)
# (138, 6)
# (138, 6)
# (138, 6)
# (136, 6)
# (136, 6)
# (135, 6)
# (134, 6)
# (134, 6)
# (134, 6)
# (133, 6)
# (131, 6)
# (129, 6)
# (129, 6)
# (128, 6)
# (128, 6)
# (127, 6)
# (127, 6)
# (126, 6)
# (126, 6)
# (124, 6)
# (124, 6)
# (124, 6)
# (124, 6)
# (122, 6)
# (121, 6)
# (121, 6)
# (120, 6)
# (120, 6)
# (119, 6)
# (117, 6)
# (116, 6)
# (116, 6)
# (116, 6)
# (113, 6)
# (112, 6)
# (112, 6)
# (110, 6)
# (110, 6)
# (110, 6)
# (109, 6)
# (107, 6)
# (107, 6)
# (105, 6)
# (105, 6)
# (105, 6)
# (104, 6)
# (104, 6)
# (104, 6)
# (103, 6)
# (101, 6)
# (100, 6)
# (100, 6)
# (99, 6)
# (99, 6)
# (97, 6)
# (97, 6)
# (96, 6)
# (95, 6)
# (95, 6)
# (93, 6)
# (93, 6)
# (93, 6)
# 390 651
# (93, 6)
# (92, 6)
# (92, 6)
# (92, 6)
# (92, 6)
# (91, 6)
# (90, 6)
# (89, 6)
# (89, 6)
# (88, 6)
# (88, 6)
# (88, 6)
# (88, 6)
# (88, 6)
# (87, 6)
# (87, 6)
# (87, 6)
# (85, 6)
# (85, 6)
# (84, 6)
# (84, 6)
# (84, 6)
# (83, 6)
# (83, 6)
# (83, 6)
# (83, 6)
# (82, 6)
# (81, 6)
# (80, 6)
# (80, 6)
# (80, 6)
# (79, 6)
# (78, 6)
# (78, 6)
# (77, 6)
# (76, 6)
# (76, 6)
# (76, 6)
# (76, 6)
# (75, 6)
# (75, 6)
# (73, 6)
# (72, 6)
# (71, 6)
# (71, 6)
# (71, 6)
# (71, 6)
# (70, 6)
# (70, 6)
# (68, 6)
# (68, 6)
# (68, 6)
# (66, 6)
# (66, 6)
# (66, 6)
# (66, 6)
# (65, 6)
# (65, 6)
# (65, 6)
# (64, 6)
# (64, 6)
# (64, 6)
# (63, 6)
# (63, 6)
# (63, 6)
# 455 651
# (62, 6)
# (61, 6)
# (60, 6)
# (60, 6)
# (59, 6)
# (59, 6)
# (59, 6)
# (57, 6)
# (57, 6)
# (57, 6)
# (56, 6)
# (55, 6)
# (55, 6)
# (54, 6)
# (54, 6)
# (53, 6)
# (53, 6)
# (53, 6)
# (52, 6)
# (52, 6)
# (51, 6)
# (51, 6)
# (51, 6)
# (51, 6)
# (50, 6)
# (50, 6)
# (50, 6)
# (49, 6)
# (49, 6)
# (49, 6)
# (48, 6)
# (48, 6)
# (47, 6)
# (47, 6)
# (46, 6)
# (46, 6)
# (46, 6)
# (46, 6)
# (46, 6)
# (45, 6)
# (44, 6)
# (44, 6)
# (44, 6)
# (44, 6)
# (43, 6)
# (43, 6)
# (43, 6)
# (43, 6)
# (43, 6)
# (43, 6)
# (42, 6)
# (42, 6)
# (42, 6)
# (42, 6)
# (42, 6)
# (42, 6)
# (42, 6)
# (41, 6)
# (41, 6)
# (41, 6)
# (40, 6)
# (39, 6)
# (39, 6)
# (38, 6)
# (38, 6)
# 520 651
# (38, 6)
# (38, 6)
# (38, 6)
# (38, 6)
# (36, 6)
# (36, 6)
# (35, 6)
# (35, 6)
# (34, 6)
# (34, 6)
# (34, 6)
# (34, 6)
# (34, 6)
# (33, 6)
# (33, 6)
# (33, 6)
# (33, 6)
# (32, 6)
# (32, 6)
# (32, 6)
# (32, 6)
# (32, 6)
# (32, 6)
# (31, 6)
# (31, 6)
# (31, 6)
# (31, 6)
# (30, 6)
# (29, 6)
# (29, 6)
# (29, 6)
# (29, 6)
# (29, 6)
# (29, 6)
# (29, 6)
# (28, 6)
# (28, 6)
# (28, 6)
# (28, 6)
# (28, 6)
# (28, 6)
# (28, 6)
# (28, 6)
# (27, 6)
# (27, 6)
# (27, 6)
# (27, 6)
# (27, 6)
# (26, 6)
# (26, 6)
# (26, 6)
# (26, 6)
# (26, 6)
# (25, 6)
# (25, 6)
# (24, 6)
# (24, 6)
# (24, 6)
# (23, 6)
# (22, 6)
# (22, 6)
# (22, 6)
# (22, 6)
# (21, 6)
# (21, 6)
# 585 651
# (21, 6)
# (21, 6)
# (20, 6)
# (20, 6)
# (20, 6)
# (20, 6)
# (19, 6)
# (19, 6)
# (19, 6)
# (18, 6)
# (18, 6)
# (18, 6)
# (18, 6)
# (18, 6)
# (18, 6)
# (18, 6)
# (17, 6)
# (17, 6)
# (17, 6)
# (16, 6)
# (16, 6)
# (16, 6)
# (16, 6)
# (15, 6)
# (15, 6)
# (15, 6)
# (15, 6)
# (15, 6)
# (15, 6)
# (15, 6)
# (15, 6)
# (15, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (14, 6)
# (13, 6)
# (13, 6)
# (13, 6)
# (12, 6)
# (12, 6)
# (12, 6)
# (12, 6)
# (12, 6)
# (12, 6)
# (12, 6)
# (12, 6)
# (11, 6)
# (11, 6)
# (11, 6)
# (11, 6)
# (11, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# (10, 6)
# 650 651
# (10, 6)
# veterinary
# ['b4d0d965-e2c5-c33f-2655-0be5de3e8c2a'
#  '1ae42845-f54f-2683-05f0-5e5b2c0b38f9'
#  '1eb5764e-21ca-9b3a-7e62-ffa6bd38b35d'
#  '51f9bd0d-b469-27a3-ea1f-b3541ed17ec3'
#  '7be9ad03-310b-ef5b-51fb-5ffff6a77712'
#  '89e1799c-2274-4e5c-a5df-cdd02547617b'
#  '936db37a-83a9-5dff-7be5-dcc7e1b54c93'
#  'c06fab5e-2646-a238-a280-1ce83e63f507']

# %%
THRESHOLD = 0.7
TOP_K = 20
# # TOP VC 들에 대해서 그들이 빨리 투자하는 카테고리, 단어 클러스터 찾기
category2investor = pickle.load(open('../data/others/category2investor.pickle'))
investor2category = pickle.load(open('../data/others/investor2category.pickle'))

word2investor = pickle.load(open('../data/others/word2investor.pickle'))
investor2word = pickle.load(open('../data/others/investor2word.pickle'))

# central = pickle.load(open(util_folder + 'investor_centrality_degree.pickle'))
central = pickle.load(open(util_folder + 'investor_centrality_between_one_over_k.pickle'))
if 'model' not in globals():
    print('loading word2vec model')
    global model
    model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')

category_distribution = {}

top20 = [uuid for uuid, value in central[:TOP_K]]
for i, uuid in enumerate(top20):
    print df_investors[df_investors['uuid'] == (uuid)]['investor_name'].values[0], central[i][1]
    categories = investor2category.get(uuid, [])
    words = investor2word.get(uuid, [])
    print "Num Categories:",len(categories), "Num Words:", len(words)
    print categories
    for category in categories:
        category_distribution[category] = category_distribution.get(category, 0) + 1

    word_list = words
    groups = {0 : [word_list[0]]}
    next_index = 1
    for word1 in word_list[1:]:
        found = False
        for index, group in groups.items():
            for word2 in group:
                if model.similarity(word1, word2) > THRESHOLD:
                    found = True
                    _index = index
                    break
            if found:
                break
        if found:
            groups[_index].append(word1)
        else:
            groups[next_index] = [word1]
            next_index += 1
    sorted_groups = sorted(groups.items(), key = lambda i: len(i[1]))
    sorted_groups.reverse()
    for index in range(min(next_index, 15)):
        if len(sorted_groups[index][1]) > 1:
            for word in sorted_groups[index][1]:
                print word,
            print
            print
    print "*"*20
print
category_distribution = sorted(category_distribution.items(), key = lambda x: x[1], reverse = True)
for word, count in category_distribution:
    print word, count, '/' , TOP_K
# Out:
# loading word2vec model
# ----------------------------------------------------------------------
# IOError                              Traceback (most recent call last)
# <ipython-input-16-23906bf47fe9> in <module>()
#      13     print('loading word2vec model')
#      14     global model
# ---> 15     model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')
#      16
#      17 category_distribution = {}
#
# /home/joonheekim/anaconda2/lib/python2.7/site-packages/gensim/models/word2vec.pyc in load(cls, *args, **kwargs)
#    1410     @classmethod
#    1411     def load(cls, *args, **kwargs):
# -> 1412         model = super(Word2Vec, cls).load(*args, **kwargs)
#    1413         # update older models
#    1414         if hasattr(model, 'table'):
#
# /home/joonheekim/anaconda2/lib/python2.7/site-packages/gensim/utils.pyc in load(cls, fname, mmap)
#     274         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     275
# --> 276         obj = unpickle(fname)
#     277         obj._load_specials(fname, mmap, compress, subname)
#     278         logger.info("loaded %s", fname)
#
# /home/joonheekim/anaconda2/lib/python2.7/site-packages/gensim/utils.pyc in unpickle(fname)
#     933 def unpickle(fname):
#     934     """Load pickled object from `fname`"""
# --> 935     with smart_open(fname, 'rb') as f:
#     936         # Because of loading from S3 load can't be used (missing readline in smart_open)
#     937         if sys.version_info > (3, 0):
#
# /home/joonheekim/anaconda2/lib/python2.7/site-packages/smart_open/smart_open_lib.pyc in smart_open(uri, mode, **kw)
#     138             # local files -- both read & write supported
#     139             # compression, if any, is determined by the filename extension (.gz, .bz2)
# --> 140             return file_smart_open(parsed_uri.uri_path, mode)
#     141         elif parsed_uri.scheme in ("s3", "s3n", "s3u"):
#     142             kwargs = {}
#
# /home/joonheekim/anaconda2/lib/python2.7/site-packages/smart_open/smart_open_lib.pyc in file_smart_open(fname, mode)
#     642
#     643     """
# --> 644     return compression_wrapper(open(fname, mode), fname, mode)
#     645
#     646
#
# IOError: [Errno 2] No such file or directory: '../util/word2vec'

# %%
get_early_investors('drone', early_investment_percent = 10, top_k = 30)

# %%
get_early_investors(['robotics'], early_investment_percent = 10, top_k = 30)

# %%
related_words(['robotics'])

# %%
get_early_investors(related_words(['robotics']), early_investment_percent = 10, top_k = 30)

# %%
get_early_investors('mobile', early_investment_percent = 10, top_k = 30)

# %%
get_early_investors('fintech', early_investment_percent = 10, top_k = 30)

# %%
get_early_investors('artificial intelligence', early_investment_percent = 10, top_k = 30)

# %%
get_early_investors('consumer', early_investment_percent = 10, top_k = 30)

# %%
get_early_investors('health care', early_investment_percent = 10, top_k = 30)

# %%
get_early_investors('craft beer', early_investment_percent = 10, top_k = 30)
