# %%
'''
주제/키워드가 주어졌을때 다음을 시각화 한다
1. 구글 트렌드
2. 투자
3. 인수
'''
# Out:
# '\n\xec\xa3\xbc\xec\xa0\x9c/\xed\x82\xa4\xec\x9b\x8c\xeb\x93\x9c\xea\xb0\x80 \xec\xa3\xbc\xec\x96\xb4\xec\xa1\x8c\xec\x9d\x84\xeb\x95\x8c \xeb\x8b\xa4\xec\x9d\x8c\xec\x9d\x84 \xec\x8b\x9c\xea\xb0\x81\xed\x99\x94 \xed\x95\x9c\xeb\x8b\xa4\n1. \xea\xb5\xac\xea\xb8\x80 \xed\x8a\xb8\xeb\xa0\x8c\xeb\x93\x9c\n2. \xed\x88\xac\xec\x9e\x90\n3. \xec\x9d\xb8\xec\x88\x98\n'

# %%
import pandas as pd
import re
import gensim
import pickle
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# load data
data_folder = '../data/csv_export/'
util_folder = '../util/'
trend_folder = '../data/trends/'
df_organizations = pd.read_csv(data_folder + 'organizations.csv'.format(data_folder), dtype={'first_funding_on': str, 'last_funding_on':str})
df_description = pd.read_csv(data_folder + 'organization_descriptions.csv')
df_funding_rounds = pd.read_csv(data_folder + 'funding_rounds.csv')
df_funds = pd.read_csv(data_folder + 'funds.csv')
df_investments = pd.read_csv(data_folder + 'investments.csv')
df_acq = pd.read_csv(data_folder + 'acquisitions.csv')

# %%
'''
주제가 주어졌을때 다음을 시각화 한다.
1. 구글 트렌드
2. 투자
3. 인수

keyword: google trend keyword (사전에 keyword.csv 이름의 파일을 trends.google.com 에서 다운 받아야 함)
words: 회사 설명에서 다음과 같은 단어가 있으면 포함시킨다.
expand: 기본 단어외의 관련 단어를 추가할 것인가?
plot_all: 3가지가 모두 나온 하나의 그래프 외에, 개별 그래프 3가지를 따로 표시할 것인가?
start_date: 시작 시점
'''
color1 = 'black'
color2 = 'grey'
color3 = '#80bfff'
color4 = 'red'


def visualize(keyword, words, expand = False, plot_all = False, start_date = '2004-01', cumulative = False):
    fig = plt.figure()
    condition = 'first_funding_on'

    # 1. google web search trend data
    df_google_trend = pd.read_csv(trend_folder + keyword + '.csv', header = 1)  
    column1, column2 = df_google_trend.columns

    df_google_trend['google_count'] = df_google_trend[column2].groupby(df_google_trend[column1].str[:7]).transform('mean')
    df_google_trend['year-month'] = df_google_trend[column1].str[:7]
    df_google_trend = df_google_trend.loc[:,['year-month', 'google_count']]
    df_google_trend = df_google_trend.drop_duplicates()
    df_google_trend.columns = ['year-month', 'google_count']
    if plot_all:
        df_google_trend.plot(kind = 'line', x = df_google_trend['year-month'], figsize = (30, 8))

    # 2. google news trend data
    df_google_news_trend = pd.read_csv(trend_folder + keyword + '_news.csv', header = 1)  
    column1, column2 = df_google_news_trend.columns
    df_google_news_trend['google_news_count'] = df_google_news_trend[column2].groupby(df_google_news_trend[column1].str[:7]).transform('mean')

    df_google_news_trend['year-month'] = df_google_news_trend[column1].str[:7]
    df_google_news_trend = df_google_news_trend.loc[:,['year-month', 'google_news_count']]
    df_google_news_trend = df_google_news_trend.drop_duplicates()
    df_google_news_trend.columns = ['year-month', 'google_news_count']
    if plot_all:
        df_google_news_trend.plot(kind = 'line', x = df_google_news_trend['year-month'], figsize = (30, 8))

    # load required dataset
    if 'word2company' not in globals():
        print('loading word2company')
        global word2company
        word2company = pickle.load(open(util_folder + 'word2company.pickle'))
    if 'model' not in globals():
        print('loading word2vec model')
        global model
        model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')

    # expand word set if necessary
    # train 된 word2vec 을 사용하여 관련도가 높은 단어들을 포함한다
    final_words = []
    if type(words) == str:
        words = [words]
    for word in words:
        if ' ' in word:
            word = word.replace(' ', '_')
        if expand:
            if word not in model: continue
            _words = model.most_similar(word)
            _words = [str(_word) for _word, sim in _words]
            final_words.extend(_words)
        final_words.append(word)
    final_words = list(set(final_words))

    # choose companies that have relevant words
    companies = []
    for word in final_words:
        _companies = word2company.get(word, [])
        companies.extend(_companies)
    companies = list(set(companies))

    if not cumulative: # just to print once
        print('Google Trend: {}\n Companies with keywords:{}'.format(keyword, final_words))

    # 회사를 시기 별로 정리한다
    # 3. funding
#     df_funding = df_funding_rounds[['company_uuid', 'funding_round_uuid', 'announced_on']]
    df = pd.DataFrame(pd.concat([df_funding_rounds[df_funding_rounds['company_uuid'].isin(companies)]['announced_on']]))
`    
#     df_companies = df_organizations[df_organizations['uuid'].isin(companies)]
#     df = pd.DataFrame()
#     df['date'] = df_companies["first_funding_on"]
#     df = df[~df['date'].isnull()]
#     df['year-month'] = df['date'].str[:7]
    
    funding = df.groupby(df['year-month']).size().reset_index()
    funding.columns = ['year-month', 'funding_count']
    funding = funding[funding['year-month'] >= start_date]
    if plot_all:
        funding.plot(kind = 'bar', x = funding['year-month'], figsize = (30, 8))


    df_merged = pd.merge(df_google_trend, funding, on = 'year-month', how = 'outer')
    df_merged = df_merged.merge(df_google_news_trend, on = 'year-month', how = 'outer')

    # 4. acquisition
    df = df_acq[df_acq['acquiree_uuid'].isin(companies)]
    if not cumulative:
#         print(df[['acquiree_name', 'acquirer_name', 'acquired_on']].sort_values('acquired_on'))
        to_print = df.sort_values('acquired_on')[['acquired_on', 'acquiree_name']]
        to_print['acquiree_name'] = to_print['acquiree_name'].apply(lambda x: x[:15])
        to_print = to_print.to_string(index = False)
        print(to_print)
#         print df.to_string(index=False)

    df = df.loc[:,['acquired_on']]
    df['year-month'] = df['acquired_on'].str[:7]
    acq = df.groupby(df['year-month']).size().reset_index()
    acq.columns = ['year-month', 'acq_count']
    acq = acq[acq['year-month'] >= start_date]

    if plot_all:
        acq.plot(kind = 'bar', x = acq['year-month'], figsize = (30, 8))

    df_merged = pd.merge(df_merged, acq, on = 'year-month', how = 'outer')
    df_merged = df_merged.sort_values(['year-month'])    
    df_merged['year'] = np.where(df_merged['year-month'].str[5:7] == '01', df_merged['year-month'].str[:4], '')

    if cumulative:
        df_merged['funding_count'] = df_merged['funding_count'].fillna(0)
        df_merged['funding_count'] = df_merged['funding_count'].cumsum()

        div_by = 100.0 / (df_merged['funding_count'].max() + 1)
        df_merged['google_count'] /= div_by
        df_merged['google_news_count'] /= div_by

        df_merged['acq_count'] = df_merged['acq_count'].fillna(0)
        df_merged['acq_count'] = df_merged['acq_count'].cumsum()
        df_merged['acq_count'] /= ((df_merged['acq_count'].max()) / (df_merged['funding_count'].max() + 1))

        df_merged[['year-month', 'google_count', 'google_news_count', 'funding_count', 'acq_count']].plot(x = df_merged['year'], linestyle = '-', color = [color1, color2, color3, color4], fontsize = 25, figsize = (30, 8)).legend(loc = 2, fontsize = 20, labels = ['google web search trend', 'google news trend', '# funding',  '# M&A',])


    else:        

        div_by = 100.0 / (df_merged['funding_count'].max() + 1)
        df_merged['google_count'] /= div_by
        df_merged['google_news_count'] /= div_by


        ax = df_merged[['year-month', 'google_count', 'google_news_count']].plot(x = df_merged['year'], linestyle = '-', color = [color1, color2])
        df_merged[['year-month', 'funding_count', 'acq_count']].plot(x = df_merged['year'], kind = 'bar', rot = 0, ax = ax, fontsize = 25, figsize = (30, 8), color = [color3, color4]).legend(loc = 2, fontsize = 20, labels = ['google web search trend', 'google news trend', '# funding', '# M&A'])

def visualize_all(keyword, words, expand = False, plot_all = False, start_date = '2004-01'):
    visualize(keyword, words, expand = expand, plot_all = plot_all, start_date = start_date, cumulative = False)
    visualize(keyword, words, expand = expand, plot_all = plot_all, start_date = start_date, cumulative = True)

# %%
visualize_all('augmented_reality', ['augmented_reality'], expand = False, plot_all = False)
# Out:
# Google Trend: augmented_reality
#  Companies with keywords:['augmented_reality']
# acquired_on    acquiree_name
# 2012-02-23             Vibe
# 2012-10-03          Viewdle
# 2013-04-10          iOnRoad
# 2015-01-01         Caugnate
# 2015-05-13      ARToolworks
# 2015-05-28           Metaio
# 2015-09-15         Looksery
# 2015-09-24   Singapore Dine
# 2015-10-13      Pikato, Inc
# 2015-11-03          Vuforia
# 2015-12-20      Drishya360s
# 2016-04-25  cherrypicks alp
# 2016-05-06  ADS Reality Ltd
# 2016-08-11        3DPhy.com
# 2016-08-30          TrumpIt
# 2016-12-12  mwf-technology
# 2016-12-13  Greenlight Insi
# 2017-04-13      XPerception

# %%
visualize_all('wearable', ['wearable', 'wearables', 'smartwatch', 'smart_glasses', 'wearable_device', 'wrist_worn', 'wearable_sensor', 'wearable_devices', 'wearable', 'wearable_tech', 'wearable_technology'], plot_all = False)
# Out:
# Google Trend: wearable
#  Companies with keywords:['wearable_tech', 'wearables', 'smartwatch', 'smart_glasses', 'wearable_device', 'wrist_worn', 'wearable_sensor', 'wearable_devices', 'wearable', 'wearable_technology']
# acquired_on    acquiree_name
# 1999-03-02      Club Monaco
# 2004-11-01       Dspfactory
# 2005-08-03          Itronix
# 2008-12-08       Textronics
# 2010-09-07  Anaconda Sports
# 2010-09-17  The ERGObaby Ca
# 2011-03-22       C2O Mobile
# 2011-07-01      AppMade Lab
# 2012-04-13     Camera Corps
# 2012-07-31    Tonalite B.V.
# 2013-04-11       Fibers.com
# 2013-04-30        BodyMedia
# 2013-06-27  Tibion Bionic T
# 2013-07-18       PrimeSense
# 2013-08-31        WIMM Labs
# 2013-11-08    Bottle Rocket
# 2014-02-19  Skyhook Wireles
# 2014-04-06  ZXY Sport Track
# 2014-12-05          Visijax
# 2014-12-05  ICE ID Solution
# 2014-12-17    Vergence Labs
# 2015-01-21  Composyt Light
# 2015-03-11             Kili
# 2015-06-01  Clothing Plus O
# 2015-09-10         CogniVue
# 2015-09-29  PA Consulting G
# 2015-10-21          SanDisk
# 2015-10-29        Binocular
# 2015-11-12  Misfit Wearable
# 2015-12-02  ONtheGO Platfor
# 2016-01-29      Flyby Media
# 2016-02-10   CareKit Health
# 2016-05-18             Coin
# 2016-08-02    News Republic
# 2016-09-01  Dymedex Consult
# 2016-09-06         Movidius
# 2016-10-24       Eyefluence
# 2016-10-27  NXP Semiconduct
# 2016-11-15        CloudMade
# 2016-12-05      Tiny Hearts
# 2016-12-06  Newgen Distribu
# 2016-12-12  Cronologics Cor
# 2017-01-04             Jiff
# 2017-01-10     Vector Watch
# 2017-01-11       Tazer Wear
# 2017-02-16            Idean
# 2017-02-27           Pocket
# 2017-03-01     Olio Devices
# 2017-03-15  Monica Healthca
# 2017-03-20    3ti Solutions
# 2017-05-11  Cupola Technolo
# 2017-05-24          Fit Pay
# 2017-05-30           Stanfy
# 2017-06-07        GreatCall
# 2017-06-08          Gait Up

# %%
visualize_all('iot', 'iot', expand = False, plot_all = False)
# Out:
# Google Trend: iot
#  Companies with keywords:['iot']
# acquired_on    acquiree_name
# 2003-03-31            Azlan
# 2006-08-21        Qualphone
# 2007-09-24       NetRegulus
# 2010-11-01            Stuzo
# 2012-08-03       SpringSoft
# 2014-02-19  Skyhook Wireles
# 2014-03-19  P-Device System
# 2014-06-10         Viryanet
# 2014-10-07           Radius
# 2014-12-01          Octoblu
# 2015-01-20  Red Bend Softwa
# 2015-01-22   Annapurna Labs
# 2015-02-10   Wireless Logic
# 2015-03-12         2lemetry
# 2015-03-18  Vitesse Semicon
# 2015-03-20  Coversant, Inc.
# 2015-03-30  Feeney Wireless
# 2015-04-30  LightMiner Syst
# 2015-06-04      TierConnect
# 2015-07-30   Sansa Security
# 2015-08-27       SeeControl
# 2015-09-24      AppCarousel
# 2015-10-26        ParStream
# 2016-01-12           Emmoco
# 2016-01-21  Unikernel Syste
# 2016-02-03   Jasper @ Cisco
# 2016-02-23        BlueKloud
# 2016-04-12       Skygistics
# 2016-04-18  GreenPeak Techn
# 2016-04-21  Device Authorit
# 2016-04-28  Broadcom's Wire
# 2016-06-16       Connode AB
# 2016-06-21  FalconX Acceler
# 2016-06-21          Ericpol
# 2016-06-30  whatever mobile
# 2016-07-07          DGLogik
# 2016-07-27  L-Com Global Co
# 2016-08-17        Dojo Labs
# 2016-08-19  Extensys - Inte
# 2016-09-12    Maven Systems
# 2016-09-28         PLAT.ONE
# 2016-10-03          Micrium
# 2016-11-09  Machina Researc
# 2017-02-20         Mistbase
# 2017-03-02            Loopd
# 2017-03-14  Meerchant, Inc.
# 2017-03-20    3ti Solutions
# 2017-04-19           InLogg
# 2017-05-11  Cupola Technolo
# 2017-05-24         MODELiiS
# 2017-05-30           Stanfy
# 2017-05-30         Carriots
# 2017-06-05     Prosa S.r.l.
# 2017-06-15  Weather Telemat
# 2017-06-20       codebender
# 2017-06-21     LCC Pakistan

# %%
visualize_all('bitcoin', 'bitcoin', expand = True, plot_all = False)
# Out:
# Google Trend: bitcoin
#  Companies with keywords:['digital_currencies', 'blockchain_technology', 'litecoin', 'bitcoins', 'crypto_currency', 'bitcoin', 'cryptocurrencies', 'cryptocurrency', 'crypto_currencies', 'digital_currency', 'bitcoin_litecoin']
# acquired_on    acquiree_name
# 2013-09-26        Braintree
# 2013-12-24        ZeroBlock
# 2014-11-21  Justcoin Exchan
# 2014-12-01         yBitcoin
# 2014-12-16  Bongo Internati
# 2015-01-21  Bitcoin Magazin
# 2015-03-19   CoinTrader.net
# 2015-04-08         Cavirtex
# 2015-04-13       BuyBitcoin
# 2015-05-04   Bitcoin Brains
# 2015-06-25            Hyper
# 2015-06-25    Bits Of Proof
# 2015-07-02  Blockchain Tech
# 2015-08-01    Coin Republic
# 2015-08-12         Coinzone
# 2015-09-16  Unisend Latinam
# 2015-10-01        Coin Fire
# 2016-01-13         CoinDesk
# 2016-01-17       Coinsetter
# 2016-01-17         Cavirtex
# 2016-06-06         BitQuick
# 2016-06-14     XBT Provider
# 2016-07-20       BlockTrail
# 2016-07-27     GreenAddress
# 2016-08-01        Bitinvest
# 2016-12-13          Glidera
# 2017-01-16  PayCash Europe
# 2017-03-24  The LTB Network
# 2017-05-30  Titcoins Digita

# %%
visualize_all('blockchain', 'blockchain', expand = False, plot_all = False)
# Out:
# Google Trend: blockchain
#  Companies with keywords:['blockchain']
# acquired_on    acquiree_name
# 2014-12-01         yBitcoin
# 2015-07-02  Blockchain Tech
# 2015-10-29    Blockstack.io
# 2016-06-08  Canaan Creative
# 2017-01-26        KreateIoT
# 2017-01-30        Lawnmower
# 2017-02-27             Skry
# 2017-04-04          Remitsy
# 2017-04-12           nChain
# 2017-05-20  Proof of Existe

# %%
visualize_all('deep_learning', 'deep learning', expand = False, plot_all = False)
# Out:
# Google Trend: deep_learning
#  Companies with keywords:['deep_learning']
# acquired_on    acquiree_name
# 2008-08-06       Parascript
# 2014-10-23   Dark Blue Labs
# 2014-10-23   Vision Factory
# 2015-03-04       AlchemyAPI
# 2015-10-05        Perceptio
# 2015-12-01           Orbeus
# 2016-08-09          Nervana
# 2016-08-16            SAIPS
# 2016-09-29  Wireless System
# 2017-01-13          Maluuba
# 2017-03-29       Siftr Labs
# 2017-04-05     ViDi Systems
# 2017-05-17           niland

# %%
visualize_all('drone', 'drone', expand = True, plot_all = False)
# Out:
# Google Trend: drone
#  Companies with keywords:['remotely_operated', 'drone', 'uas', 'unmanned_aerial', 'uav', 'unmanned', 'uavs', 'drones', 'unmanned_aircraft', 'vtol', 'fixed_wing']
# acquired_on    acquiree_name
# 2000-02-02    2B Technology
# 2006-01-06     Miltec Corp.
# 2006-06-21  Enerdyne Techno
# 2008-03-03  Athena Technolo
# 2008-06-03  Intelligent Aut
# 2008-07-16  Soil Machine Dy
# 2009-03-12  Advanced Cerami
# 2009-05-01  Cloud Cap Techn
# 2009-11-20  Submersible Tec
# 2010-01-22  Crossbow Techno
# 2010-01-25  Science, Engine
# 2010-08-09  Airborne Techno
# 2010-09-27  McKechnie Aeros
# 2011-01-13              LNX
# 2011-06-03  Crossbow Techno
# 2012-04-06         Gatewing
# 2012-05-31  Teledyne BlueVi
# 2012-11-13  Chandler/May, I
# 2012-12-17         ShotOver
# 2013-05-16  Arkwin Industri
# 2014-03-28     Ascenta (UK)
# 2014-04-14  Titan Aerospace
# 2014-09-03  Bolt Technology
# 2015-01-30  Engineering Sol
# 2015-02-09  Soil Machine Dy
# 2015-06-10  Broadcast Micro
# 2015-07-01            TREXA
# 2015-07-20  Adaptive Flight
# 2015-07-20  Sikorsky Aircra
# 2015-10-29        Binocular
# 2015-11-25           Z-eyez
# 2015-12-14        PrismTech
# 2016-01-04  Ascending Techn
# 2016-04-05  Green Sustainab
# 2016-05-19             AC&A
# 2016-06-04           Skybag
# 2016-07-06             901D
# 2016-09-01  Advanced Reconn
# 2016-09-22          Redbird
# 2016-10-04  Triumph Aerospa
# 2016-10-20  Unmanned Safety
# 2016-10-31    Erle Robotics
# 2016-11-01     MAVinci GmbH
# 2016-11-03  CES Creative El
# 2016-11-15  Autoflight Logi
# 2016-11-21  Vantage Vertica
# 2016-11-30    Prox Dynamics
# 2017-01-30  Pathfinder Avia
# 2017-02-16          Skyward
# 2017-05-12     EuroAvionics
# 2017-05-26  Ctrl Me Robotic
# 2017-06-07           AERIAL

# %%
visualize_all('social_media', 'social_media', expand = False, plot_all = False)
# Out:
# Google Trend: social_media
#  Companies with keywords:['social_media']
# acquired_on    acquiree_name
# 1998-06-28   Submit Express
# 1999-03-01   Argon Networks
# 1999-12-01             Cone
# 2001-01-17        Webtrends
# 2005-03-08  J.D. Power and
# 2005-03-29        Webtrends
# 2005-07-23         Blockdot
# 2006-03-24      Mobile-Mind
# 2006-05-22         Salesnet
# 2006-08-31       Hipcricket
# 2006-09-01       Via Caroli
# 2006-12-13  Quilter Cheviot
# 2006-12-20       DigitasLBi
# 2007-01-10  New Media Strat
# 2007-04-05        Advaliant
# 2007-04-11    Reprise Media
# 2007-07-18  Mediabistro.com
# 2007-10-01          Traffix
# 2007-12-11       stylediary
# 2008-01-31             Sway
# 2008-02-01           Snocap
# 2008-03-04            Pluck
# 2008-04-01           Umbria
# 2008-05-05    Absolute Punk
# 2008-06-25        UGENmedia
# 2008-07-15         OnlyWire
# 2008-07-16  Chirp Interacti
# 2008-08-26      Blogcritics
# 2008-09-29  Clear Blue Inte
# 2008-11-14    Ripple6, Inc.
# 2009-02-12        Mr. Youth
# 2009-03-05           SezWho
# 2009-04-08       StreetFire
# 2009-04-16         Outblaze
# 2009-06-30     PopularMedia
# 2009-07-15         Techrigy
# 2009-08-10       FriendFeed
# 2009-09-28          GovLoop
# 2009-12-01  The Barbarian G
# 2009-12-10      SocialTimes
# 2010-01-01     PromoDigital
# 2010-01-04            ShoZu
# 2010-01-07         Filtrbox
# 2010-01-13     AM Analytics
# 2010-02-24         BuzzGain
# 2010-03-03  Offbeat Creatio
# 2010-03-19  yelster digital
# 2010-03-25  Bunim Murray Pr
# 2010-04-20        BDL Media
# 2010-04-29           Biz360
# 2010-05-06       Scout Labs
# 2010-05-24     NutshellMail
# 2010-06-01          Sysomos
# 2010-06-02        iCrossing
# 2010-06-10  Help A Reporter
# 2010-06-21      Hydra Group
# 2010-07-07      BrightCloud
# 2010-07-09  The Cobalt Grou
# 2010-07-28  Conversa Market
# 2010-08-03  Relevent Partne
# 2010-09-01  Nudge Social Me
# 2010-09-01         Intrepid
# 2010-09-30          Mobclix
# 2010-10-01        SpaBooker
# 2010-11-01           Baltix
# 2010-11-12        Socializr
# 2010-12-01       Ludic Labs
# 2010-12-21  StepChange Grou
# 2010-12-30  Blue State Digi
# 2011-01-01             Mixx
# 2011-01-02       Cofa Media
# 2011-01-04    Media Factory
# 2011-01-05            Flock
# 2011-01-14         Virilion
# 2011-01-17  Techlightenment
# 2011-01-19  ObjectiveMarket
# 2011-01-25           fflick
# 2011-01-31         KickApps
# 2011-02-01     Static Media
# 2011-02-01         PalzCity
# 2011-02-02         Backyard
# 2011-02-14         KeChange
# 2011-02-16      EngineWorks
# 2011-03-01          toor.me
# 2011-03-11      6Consulting
# 2011-03-22        JitterJam
# 2011-03-30  Salesforce Radi
# 2011-04-05         Overtone
# 2011-04-06      TweetMyJobs
# 2011-04-13    Proximal Labs
# 2011-04-27         PicScout
# 2011-04-29        Crowdmass
# 2011-05-05         BuzzLabs
# 2011-05-09            Tap11
# 2011-05-09            Cimri
# 2011-05-10     Conversition
# 2011-05-16         RentPath
# 2011-06-08  ICUC Moderation
# 2011-06-08  Beeconomic Sing
# 2011-06-16     VinSolutions
# 2011-06-16      Performable
# 2011-06-27          GoNabit
# 2011-06-28      Socialblaze
# 2011-07-01         Cupónica
# 2011-07-05         BackType
# 2011-07-06    Echelon Media
# 2011-07-11  Screamin Daily
# 2011-07-14        JustMeans
# 2011-07-19           CLANMO
# 2011-07-20      JustSpotted
# 2011-08-04       Hipcricket
# 2011-08-09     RSS Graffiti
# 2011-08-17          Yoohoot
# 2011-08-18  Autonomy Corpor
# 2011-08-22          Evolver
# 2011-09-01          OneRiot
# 2011-09-07       Keepstream
# 2011-09-08              DAD
# 2011-09-15           mokono
# 2011-09-21         Desk.com
# 2011-10-01      MetroLyrics
# 2011-10-01        Thingbuzz
# 2011-10-04  SpinLabel Techn
# 2011-10-10         ethority
# 2011-10-14         Flowtown
# 2011-11-01           Qwerly
# 2011-11-08       CRM Metrix
# 2011-11-14        Mr. Youth
# 2011-11-14              MRY
# 2011-11-30  Efficient Front
# 2011-12-15            Roost
# 2011-12-15      InfoGlutton
# 2012-01-04   Solar Velocity
# 2012-01-18        MediaGong
# 2012-01-25       AllRecipes
# 2012-02-02          Reppler
# 2012-02-11  WisePatient, LL
# 2012-02-22        Roundarch
# 2012-02-28         iContact
# 2012-03-05           Dotbox
# 2012-03-29        Texterity
# 2012-04-17      Hotspots.io
# 2012-05-02          eCircle
# 2012-05-03  LinkedIn SlideS
# 2012-05-08          Entiera
# 2012-05-16   Sundrop Mobile
# 2012-05-16        Moonfruit
# 2012-05-22        Audiolife
# 2012-06-04            Meebo
# 2012-06-14       MuseGlobal
# 2012-06-18  Seamless Receip
# 2012-07-10         Involver
# 2012-07-26   Spot Influence
# 2012-07-31         Wildfire
# 2012-08-08            HEXA2
# 2012-08-12  Daruma Concept
# 2012-08-14   Ant's Eye View
# 2012-08-23      BuzzNumbers
# 2012-08-30             AKMG
# 2012-09-05          Seesmic
# 2012-09-13  The Material Gr
# 2012-09-13      SocialKandy
# 2012-09-13  PredictiveInten
# 2012-09-17   Arkovi Backups
# 2012-09-20       Flavors.me
# 2012-09-25             EQAL
# 2012-10-03          Viewdle
# 2012-10-09             Vine
# 2012-10-09    Social Dynamx
# 2012-10-17          tarpipe
# 2012-11-02         Postling
# 2012-11-05     Social Shore
# 2012-12-13     Outside Line
# 2013-01-07    Zenfolio, Inc
# 2013-01-20      LGBT Social
# 2013-01-22     DiscoverText
# 2013-01-22        GroSocial
# 2013-01-28         Payvment
# 2013-02-04     Bluefin Labs
# 2013-02-26       Noot, Inc.
# 2013-02-26      Lonelybrand
# 2013-02-27          TunedIn
# 2013-03-11     SMG Convonix
# 2013-03-14       Hot Studio
# 2013-03-19  Fashion Traffic
# 2013-03-26        VoterTide
# 2013-04-01         StatsMix
# 2013-04-09  Connections Med
# 2013-04-18  Neev Informatio
# 2013-04-30       Semantelli
# 2013-05-02              NVI
# 2013-05-13       Lucky Sort
# 2013-05-16         ElisaDBI
# 2013-05-20          Mogreet
# 2013-05-22           Aptito
# 2013-06-12  myStaffingPro b
# 2013-07-10           Net@lk
# 2013-07-11       TwentyFeet
# 2013-07-25  VerticalRespons
# 2013-07-30      Red Digital
# 2013-07-31    ElementsLocal
# 2013-07-31    Bounce Energy
# 2013-08-01           Optify
# 2013-08-02           JetJaw
# 2013-08-06      Whitevector
# 2013-08-07  Ephricon Web Ma
# 2013-08-15         Syncapse
# 2013-08-29          Espalhe
# 2013-09-09          Storify
# 2013-09-09  Editions Publis
# 2013-09-26           SaaSID
# 2013-10-01      ITNavigator
# 2013-10-01          Adquant
# 2013-10-13  SocialRankz (A
# 2013-10-13            Bread
# 2013-10-16      RentAdvisor
# 2013-10-16    Optimal, Inc.
# 2013-10-20    Banyan Branch
# 2013-11-08  Visual Intellig
# 2013-11-11   TOFU Marketing
# 2013-11-12   Movitas Mobile
# 2013-11-21    PRunderground
# 2013-11-21    Biggs|Gilmore
# 2013-12-02  Synergize Digit
# 2013-12-04  Critical Path I
# 2013-12-05   The New Agency
# 2013-12-11       Quest Fore
# 2013-12-11        Macromill
# 2013-12-16         Wetpaint
# 2013-12-20         Storyful
# 2014-01-01            Pheed
# 2014-01-02        DigaForce
# 2014-01-06    KANA Software
# 2014-01-22           uberVU
# 2014-01-22       Integrasco
# 2014-01-27        Infoition
# 2014-02-06      CloudSquads
# 2014-03-01         PromoJam
# 2014-03-10      Blayze Inc.
# 2014-03-17         Flavorus
# 2014-03-17  Welcome Home Bl
# 2014-03-18  Epiphany Soluti
# 2014-03-28       SharedBook
# 2014-03-28            MagMo
# 2014-03-31        Mesagraph
# 2014-03-31         FusePump
# 2014-04-01          Evently
# 2014-04-02   Mass Relevance
# 2014-04-02             dtms
# 2014-04-07        8thBridge
# 2014-04-08       OwenKessel
# 2014-04-15       FeedMagnet
# 2014-04-16    BrightContext
# 2014-04-24        Ideavibes
# 2014-04-30  Cell Journalist
# 2014-05-05  SEO Site Wizard
# 2014-05-16          CalmSea
# 2014-05-21              AMX
# 2014-05-28             mktg
# 2014-06-02            Vocus
# 2014-06-03  G. Wang Communi
# 2014-06-05         Haygarth
# 2014-06-10  Adconion Media
# 2014-06-16        Fusion-io
# 2014-06-19         SnappyTV
# 2014-06-25    moviepilot.de
# 2014-06-30          tweetTV
# 2014-07-14     RSS Graffiti
# 2014-07-17  BuzzFactory Int
# 2014-07-22         AdCenter
# 2014-07-23         Eventful
# 2014-07-23        Entrinsic
# 2014-07-29       MediaMiser
# 2014-07-30  The Engine Grou
# 2014-08-01     Convometrics
# 2014-08-11             Gnip
# 2014-08-14      TBG Digital
# 2014-08-22           Bubbly
# 2014-09-03      ShopIgniter
# 2014-09-08  Crazy For the B
# 2014-09-15  Visible Technol
# 2014-09-15    Content Savvy
# 2014-09-15          Adquant
# 2014-09-18        Promoqube
# 2014-09-22           Engodo
# 2014-09-23   LocalVox Media
# 2014-09-25            Zeetl
# 2014-09-29   Tibco software
# 2014-10-03          Voxtron
# 2014-10-08        Liquorice
# 2014-10-08        AdJuggler
# 2014-10-14  You Everywhere
# 2014-10-17  Quilter Cheviot
# 2014-10-24       Filemobile
# 2014-11-03          BlogHer
# 2014-11-07       Socialgist
# 2014-11-10  IntelliResponse
# 2014-11-17         Halalati
# 2014-11-17       ChyronHego
# 2014-12-01    Argyle Social
# 2014-12-09        Addvocate
# 2014-12-17             Scan
# 2014-12-17        PeerIndex
# 2015-01-01       Teal Orbit
# 2015-01-08  Thought Mechani
# 2015-01-28      Songstagram
# 2015-01-30       WATConsult
# 2015-02-03           Avocis
# 2015-02-11       Eventifier
# 2015-02-11            Niche
# 2015-02-16  Soap Linked by
# 2015-02-16        TheBlogTV
# 2015-02-17  The Weather Dig
# 2015-02-25          Betabox
# 2015-02-26            Pluck
# 2015-03-03       ADPLUS IND
# 2015-03-17    MarketMeSuite
# 2015-03-20   cynergyMC, LLC
# 2015-03-24        Viralheat
# 2015-03-31       CLX Europe
# 2015-04-01           EzLike
# 2015-04-08  Ipanema Technol
# 2015-04-15    SocialExpress
# 2015-04-24         Postcron
# 2015-04-30             Scup
# 2015-05-04          McBeard
# 2015-05-15          Re fame
# 2015-05-15         New Look
# 2015-05-19  Simply Social M
# 2015-05-19   Next Big Sound
# 2015-05-21          Engagor
# 2015-05-29    Fit Marketing
# 2015-06-02  newBrandAnalyti
# 2015-06-12  Zero 3 Computer
# 2015-06-18        Venuelabs
# 2015-06-18        Sparkflow
# 2015-06-29    GoLoyal, Inc.
# 2015-07-09     Instafluence
# 2015-07-17         Intygral
# 2015-07-20            Swayy
# 2015-07-23     GraphScience
# 2015-08-01    Movie Manager
# 2015-08-17     Computerlogy
# 2015-08-19         Shoutlet
# 2015-08-21     King Content
# 2015-09-01    Inside Social
# 2015-09-04        SharedVue
# 2015-09-10  The Creative Co
# 2015-09-10    Empire Avenue
# 2015-09-14             Tuee
# 2015-09-14       Gazemetrix
# 2015-09-16  LikeLive | Zip
# 2015-09-23      Wisemetrics
# 2015-10-07          YouScan
# 2015-10-08        Spotistic
# 2015-10-08           Frubis
# 2015-10-10          boo-box
# 2015-10-13         DataRank
# 2015-10-16        ActSocial
# 2015-10-19  ZoomOn Platform
# 2015-10-22       Nickelfish
# 2015-10-22  ZoneFranche SAS
# 2015-11-01         Socially
# 2015-11-02  Constant Contac
# 2015-11-02            Bloxx
# 2015-11-04       Socialware
# 2015-11-26   Creative Spark
# 2015-12-04   Socialytics.io
# 2015-12-07  The Cobalt Grou
# 2015-12-07        InQuicker
# 2015-12-08             Pext
# 2016-01-06        Mainstack
# 2016-01-07  BurnThis, Inc.
# 2016-01-12      Netbox Blue
# 2016-01-14      ListenLogic
# 2016-01-27  Ameriteck Web S
# 2016-01-28  Really Good Stu
# 2016-02-09   Beanstalk Data
# 2016-02-11            Queue
# 2016-02-11      Marketwired
# 2016-02-16    BrightWhistle
# 2016-02-17  Activate by Blo
# 2016-02-22  Apex Communicat
# 2016-02-29           Vemory
# 2016-02-29  Glow Digital Me
# 2016-03-07        OneTwoSee
# 2016-03-10    Reputami GmbH
# 2016-03-11           UpWord
# 2016-03-11         Publitek
# 2016-03-14       Hipcricket
# 2016-03-14  Social Media In
# 2016-03-14  Shelton Interac
# 2016-03-16          Volicon
# 2016-03-21        InNetwork
# 2016-03-22  Triggerfox Corp
# 2016-03-29    Sales Prodigy
# 2016-03-30       MWH Global
# 2016-04-01         Sitecore
# 2016-04-07          BSocial
# 2016-04-07  Iris Life Commu
# 2016-04-13       ChangeCoin
# 2016-04-13          Airwoot
# 2016-04-15  J.D. Power and
# 2016-04-18      EngageClick
# 2016-04-20  Seed Digital Lt
# 2016-04-21   Simply Recipes
# 2016-04-22      stylefruits
# 2016-04-25  Zalora Thailand
# 2016-05-10    High Position
# 2016-05-16  PR Newswire - A
# 2016-05-16  FansTang and Ch
# 2016-05-18       MutualMind
# 2016-05-18       BDBL Media
# 2016-05-20       Newsmonkey
# 2016-05-23   G1 Colourmedia
# 2016-05-26  Foodie Blogroll
# 2016-06-01  Raising iBrows
# 2016-06-04         Flavorus
# 2016-06-07           Scorch
# 2016-06-07  QuickThink Medi
# 2016-06-14          TheGrio
# 2016-06-16  Lodestone Socia
# 2016-06-17      Your Social
# 2016-06-17        Techvibes
# 2016-06-30       AA Ireland
# 2016-07-01         Almighty
# 2016-07-05  Four Health Com
# 2016-07-11     SalesPredict
# 2016-07-12          RedZone
# 2016-07-12     Attentive.ly
# 2016-07-12     Anneysen.com
# 2016-07-14  Virtual Walkthr
# 2016-07-14  Ticket Utils, I
# 2016-07-14    Easycom Group
# 2016-07-18           Adweek
# 2016-07-19      Dressabelle
# 2016-07-19  Dominion Marine
# 2016-07-19  Command Partner
# 2016-07-20  Mastermind Mark
# 2016-07-25          plug.dj
# 2016-07-26  99 Dollar Socia
# 2016-07-26   Digital Virtue
# 2016-07-26     Standing Dog
# 2016-07-27        OBILytics
# 2016-07-27          OBI4wan
# 2016-08-01         Sandboxr
# 2016-08-02       PMX Agency
# 2016-08-02    iStrategyLabs
# 2016-08-03  Gibbons Digital
# 2016-08-15  Pro Draft Leagu
# 2016-08-16       SOMEXCLOUD
# 2016-08-17    Wedding Ideas
# 2016-08-17  Chemistry Commu
# 2016-08-24         FanBread
# 2016-09-01        Westpoint
# 2016-09-13   Flipside Group
# 2016-09-16          Ladderr
# 2016-09-19  Universal Comed
# 2016-09-20  PacRim Marketin
# 2016-09-20          Orca TV
# 2016-09-27       Skinny Mom
# 2016-09-27  Pinnacle Market
# 2016-09-30  Eastwick Commun
# 2016-10-04            GWAVA
# 2016-10-05       Netscribes
# 2016-10-06           JustGo
# 2016-10-12            Wimdu
# 2016-10-18  OhSoPinterestin
# 2016-10-18      Giga Health
# 2016-10-18    Capture Media
# 2016-10-20   Soinsi Digital
# 2016-10-24     Refined Labs
# 2016-10-27       LiveAnswer
# 2016-10-27  Big Cat Enterta
# 2016-10-28           Caddis
# 2016-11-01   Ryan Solutions
# 2016-11-03             VOKE
# 2016-11-08  Bond Internatio
# 2016-11-17      Little Bird
# 2016-11-17  Collective Bias
# 2016-11-17             LSEO
# 2016-11-30            Wimdu
# 2016-11-30  North Strategic
# 2016-11-30         MegaHoot
# 2016-12-01       MinuteBuzz
# 2016-12-08       Meople.Net
# 2016-12-08         17 Media
# 2016-12-09          Zipipop
# 2016-12-15          VinTank
# 2016-12-25     Driven, Inc.
# 2017-01-01    Optimal, Inc.
# 2017-01-04       Proofhouse
# 2017-01-04        Engage PR
# 2017-01-11         Truck It
# 2017-01-12            firal
# 2017-01-13    Dekatlon Buzz
# 2017-01-16        ReviewPro
# 2017-01-17           Promio
# 2017-01-17  Media Connect P
# 2017-01-18       Adzzup Inc
# 2017-01-19          BuboBox
# 2017-01-20  Kerio Technolog
# 2017-01-27  Cartera Commerc
# 2017-02-01       Newsaccess
# 2017-02-01  G. Wang Communi
# 2017-02-02   Plum Analytics
# 2017-02-09             Cone
# 2017-02-15         Emphatic
# 2017-02-17  LookSharp (powe
# 2017-02-21  ChimeraCompanyG
# 2017-02-22        TripScope
# 2017-02-28      Buzzcapture
# 2017-03-02  My Action Repla
# 2017-03-06    Legend Engage
# 2017-03-06               L2
# 2017-03-14             WTF1
# 2017-03-14         AGENCE79
# 2017-03-16  uFluencer Group
# 2017-03-16         ModCloth
# 2017-03-21     Glue PR Ltd.
# 2017-03-28      Upplication
# 2017-03-28  Bulletin Intell
# 2017-03-31  Hallam Internet
# 2017-04-03            JSH&A
# 2017-04-04  Ying Communicat
# 2017-04-04  Turnstyle Solut
# 2017-04-15    Towers Design
# 2017-04-19        Covercake
# 2017-04-26     Sitening LLC
# 2017-05-01    Jive Software
# 2017-05-01    Court Chatter
# 2017-05-02    Web Decisions
# 2017-05-05           Lissly
# 2017-05-09  REV Asia Berhad
# 2017-05-18   Crispy Content
# 2017-05-18  Are You a Human
# 2017-05-23          TapWalk
# 2017-05-23    Digital Roots
# 2017-06-01  EMAP Publishing
# 2017-06-06         Tidemark
# 2017-06-13         Ubiquity
# 2017-06-19  Social Media Br

# %%
visualize_all('self_driving_car', ['self driving', 'autonomous driving', 'driverless', 'autonomous vehicle'], expand = False, plot_all = False)
# Out:
# Google Trend: self_driving_car
#  Companies with keywords:['autonomous_driving', 'autonomous_vehicle', 'self_driving', 'driverless']
# acquired_on    acquiree_name
# 2015-07-23       Ottomatika
# 2016-03-11  Cruise Automati
# 2016-03-29       StackStorm
# 2016-05-24  ADASENS Automot
# 2016-08-18             Otto
# 2016-12-01       MicroFuzzy

# %%
visualize_all('neuroscience', ['neuroscience'], expand = False, plot_all = False)
# Out:
# Google Trend: neuroscience
#  Companies with keywords:['neuroscience']
# acquired_on    acquiree_name
# 2004-07-26  King Pharmaceut
# 2006-04-07  Rinat Neuroscie
# 2007-04-03          Hypnion
# 2008-02-12       Abfrontier
# 2008-05-09  BIOMOL Internat
# 2008-05-14  Leica Biosystem
# 2008-11-12  JNetDirect Bios
# 2010-10-12  King Pharmaceut
# 2011-03-04   TransMolecular
# 2011-05-27       NeuroFocus
# 2012-02-17  NeuroNexus Tech
# 2014-01-21          NuPathe
# 2014-03-03    Intific, Inc.
# 2015-01-11  Convergence Pha
# 2015-04-14         ProNerve
# 2015-05-18  Innerscope Rese
# 2016-08-09          Nervana
# 2016-11-29   MTI-GlobalStem
# 2017-03-02       Neurovance
# 2017-05-01  Kangaroo Kids E
# 2017-05-31  Constant Therap

# %%
visualize_all('mobile_health_care', ['mobile health', 'mobile healthcare'], expand = True, plot_all = False)
# Out:
# Google Trend: mobile_health_care
#  Companies with keywords:[]
# Empty DataFrame
# Columns: [acquired_on, acquiree_name]
# Index: []

# %%
visualize_all('social_robot', 'social robot', expand = True, plot_all = False)
# Out:
# Google Trend: social_robot
#  Companies with keywords:[]
# Empty DataFrame
# Columns: [acquired_on, acquiree_name]
# Index: []

# %%
visualize_all('lidar', 'lidar', expand = False, plot_all = False)
# Out:
# Google Trend: lidar
#  Companies with keywords:['lidar']
# acquired_on    acquiree_name
# 2003-06-23       Lizardtech
# 2007-02-14       Inpho GmbH
# 2011-07-29  Destiny Resourc
# 2012-12-03  GTA Geoinformat
# 2013-02-01  Allpoint System
# 2014-08-01            V-Gen
# 2016-01-25  Signal Processi
# 2016-02-19      Sigma Space
# 2016-03-16  Advanced Scient

# %%
# visualize_all('chatbot', ['chatbot', 'conversational', 'chat bot', 'ibm watson', 'siri'], expand = False, plot_all = False)
visualize_all('chatbot', ['chatbot', 'chat bot', 'ibm watson', 'siri'], expand = False, plot_all = False)
# Out:
# Google Trend: chatbot
#  Companies with keywords:['chat_bot', 'chatbot', 'ibm_watson', 'siri']
# acquired_on    acquiree_name
# 2010-04-28             Siri
# 2014-03-10      Giant Media
# 2014-08-06    Emu Messenger
# 2015-01-05           Wit.ai
# 2015-05-29         Tempo AI
# 2016-02-23        BlueKloud
# 2016-10-18        Chatimity
# 2017-06-30  Chatbot Incubat

# %%
visualize_all('fintech', 'fintech', expand = False, plot_all = False)
# Out:
# Google Trend: fintech
#  Companies with keywords:['fintech']
# acquired_on    acquiree_name
# 2012-01-13       ORCA, Inc.
# 2015-03-25       Clientific
# 2015-10-27           Kusiri
# 2016-05-28     Target Group
# 2016-07-11            Sling
# 2016-10-03             Byng
# 2016-10-20  GMEX Technologi
# 2016-12-19   Working Status
# 2017-01-18         SparkFin
# 2017-05-10       Matchi.biz
# 2017-06-19          Perseus

# %%
visualize_all('3d_printing', '3d printing', expand = True, plot_all = False)
# Out:
# Google Trend: 3d_printing
#  Companies with keywords:[]
# Empty DataFrame
# Columns: [acquired_on, acquiree_name]
# Index: []

# %%
visualize_all('quantum_computing', 'quantum_computing', expand = False, plot_all = False)
# Out:
# Google Trend: quantum_computing
#  Companies with keywords:['quantum_computing']
# Empty DataFrame
# Columns: [acquired_on, acquiree_name]
# Index: []
