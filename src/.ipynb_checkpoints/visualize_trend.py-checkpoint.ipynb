# %%
'''
주제/키워드가 주어졌을때 다음을 시각화 한다
1. 구글 트렌드
2. 투자
3. 인수
'''
# Out:
# '\n\xec\xa3\xbc\xec\xa0\x9c/\xed\x82\xa4\xec\x9b\x8c\xeb\x93\x9c\xea\xb0\x80 \xec\xa3\xbc\xec\x96\xb4\xec\xa1\x8c\xec\x9d\x84\xeb\x95\x8c \xeb\x8b\xa4\xec\x9d\x8c\xec\x9d\x84 \xec\x8b\x9c\xea\xb0\x81\xed\x99\x94 \xed\x95\x9c\xeb\x8b\xa4\n1. \xea\xb5\xac\xea\xb8\x80 \xed\x8a\xb8\xeb\xa0\x8c\xeb\x93\x9c\n2. \xed\x88\xac\xec\x9e\x90\n3. \xec\x9d\xb8\xec\x88\x98\n'

# %%
import pandas as pd
import re
import gensim
import pickle
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# load data
data_folder = '../data/csv_export/'
util_folder = '../util/'
trend_folder = '../data/trends/'
df_organizations = pd.read_csv(data_folder + 'organizations.csv'.format(data_folder), dtype={'first_funding_on': str, 'last_funding_on':str})
df_description = pd.read_csv(data_folder + 'organization_descriptions.csv')
df_funding_rounds = pd.read_csv(data_folder + 'funding_rounds.csv')
df_funds = pd.read_csv(data_folder + 'funds.csv')
df_investments = pd.read_csv(data_folder + 'investments.csv')
df_acq = pd.read_csv(data_folder + 'acquisitions.csv')

# %%
color1 = 'black'
color2 = 'grey'
color3 = '#80bfff'
color4 = 'red'

keyword = 'augmented_reality'
words = ['augmented_reality', 'ar']
expand = False
plot_all = False
start_date = '2004-01'
cumulative = False

fig = plt.figure()
condition = 'first_funding_on'

# 1. google web search trend data
df_google_trend = pd.read_csv(trend_folder + keyword + '.csv', header = 1)  
column1, column2 = df_google_trend.columns

df_google_trend['google_count'] = df_google_trend[column2].groupby(df_google_trend[column1].str[:7]).transform('mean')
df_google_trend['year-month'] = df_google_trend[column1].str[:7]
df_google_trend = df_google_trend.loc[:,['year-month', 'google_count']]
df_google_trend = df_google_trend.drop_duplicates()
df_google_trend.columns = ['year-month', 'google_count']
if plot_all:
    df_google_trend.plot(kind = 'line', x = df_google_trend['year-month'], figsize = (30, 8))

# 2. google news trend data
df_google_news_trend = pd.read_csv(trend_folder + keyword + '_news.csv', header = 1)  
column1, column2 = df_google_news_trend.columns
df_google_news_trend['google_news_count'] = df_google_news_trend[column2].groupby(df_google_news_trend[column1].str[:7]).transform('mean')

df_google_news_trend['year-month'] = df_google_news_trend[column1].str[:7]
df_google_news_trend = df_google_news_trend.loc[:,['year-month', 'google_news_count']]
df_google_news_trend = df_google_news_trend.drop_duplicates()
df_google_news_trend.columns = ['year-month', 'google_news_count']
if plot_all:
    df_google_news_trend.plot(kind = 'line', x = df_google_news_trend['year-month'], figsize = (30, 8))

# load required dataset
if 'word2company' not in globals():
    print('loading word2company')
    global word2company
    word2company = pickle.load(open(util_folder + 'word2company.pickle'))
if 'model' not in globals():
    print('loading word2vec model')
    global model
    model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')

# expand word set if necessary
# train 된 word2vec 을 사용하여 관련도가 높은 단어들을 포함한다
final_words = []
if type(words) == str:
    words = [words]
for word in words:
    if ' ' in word:
        word = word.replace(' ', '_')
    if expand:
        _words = model.most_similar(word)
        _words = [str(_word) for _word, sim in _words]
        final_words.extend(_words)
    final_words.append(word)
final_words = list(set(final_words))

# choose companies that have relevant words
companies = []
for word in final_words:
    _companies = word2company.get(word, [])
    companies.extend(_companies)
companies = list(set(companies))

if not cumulative: # just to print once
    print('Google Trend: {}\n Companies with keywords:{}'.format(keyword, final_words))

# 회사를 시기 별로 정리한다
# 3. funding
df_companies = df_organizations[df_organizations['uuid'].isin(companies)]
df = pd.DataFrame()
df['date'] = df_companies["first_funding_on"]
df = df[~df['date'].isnull()]
df['year-month'] = df['date'].str[:7]
funding = df.groupby(df['year-month']).size().reset_index()
funding.columns = ['year-month', 'funding_count']
funding = funding[funding['year-month'] >= start_date]
if plot_all:
    funding.plot(kind = 'bar', x = funding['year-month'], figsize = (30, 8))


df_merged = pd.merge(df_google_trend, funding, on = 'year-month', how = 'outer')
df_merged = df_merged.merge(df_google_news_trend, on = 'year-month', how = 'outer')

# 4. acquisition
df = df_acq[df_acq['acquiree_uuid'].isin(companies)]
print(df[['acquiree_name', 'acquirer_name', 'acquired_on']].sort_values('acquired_on'))
df = df.loc[:,['acquired_on']]
df['year-month'] = df['acquired_on'].str[:7]
acq = df.groupby(df['year-month']).size().reset_index()
acq.columns = ['year-month', 'acq_count']
acq = acq[acq['year-month'] >= start_date]

if plot_all:
    acq.plot(kind = 'bar', x = acq['year-month'], figsize = (30, 8))

df_merged = pd.merge(df_merged, acq, on = 'year-month', how = 'outer')
df_merged = df_merged.sort_values(['year-month'])    
df_merged['year'] = np.where(df_merged['year-month'].str[5:7] == '01', df_merged['year-month'].str[:4], '')

if cumulative:
    df_merged['funding_count'] = df_merged['funding_count'].fillna(0)
    df_merged['funding_count'] = df_merged['funding_count'].cumsum()

    div_by = 100.0 / (df_merged['funding_count'].max() + 1)
    df_merged['google_count'] /= div_by
    df_merged['google_news_count'] /= div_by

    df_merged['acq_count'] = df_merged['acq_count'].fillna(0)
    df_merged['acq_count'] = df_merged['acq_count'].cumsum()
    df_merged['acq_count'] /= ((df_merged['acq_count'].max()) / (df_merged['funding_count'].max() + 1))

    df_merged[['year-month', 'google_count', 'google_news_count', 'funding_count', 'acq_count']].plot(x = df_merged['year'], linestyle = '-', color = [color1, color2, color3, color4], fontsize = 25, figsize = (30, 8)).legend(loc = 2, fontsize = 20, labels = ['google web search trend', 'google news trend', '# funding',  '# M&A',])

else:        
    div_by = 100.0 / (df_merged['funding_count'].max() + 1)
    df_merged['google_count'] /= div_by
    df_merged['google_news_count'] /= div_by


    ax = df_merged[['year-month', 'google_count', 'google_news_count']].plot(x = df_merged['year'], linestyle = '-', color = [color1, color2])
    df_merged[['year-month', 'funding_count', 'acq_count']].plot(x = df_merged['year'], kind = 'bar', rot = 0, ax = ax, fontsize = 25, figsize = (30, 8), color = [color3, color4]).legend(loc = 2, fontsize = 20, labels = ['google web search trend', 'google news trend', '# funding', '# M&A'])
# Out:
# Google Trend: augmented_reality
#  Companies with keywords:['ar', 'augmented_reality']
#                     acquiree_name                  acquirer_name acquired_on
# 37398                  NetRegulus    Parametric Technology (PTC)  2007-09-24
# 35782              Arius Research                          Roche  2008-07-22
# 27479                        Vibe                      Betaworks  2012-02-23
# 26270                   Bixti.com                           Elo7  2012-07-30
# 25744                     Viewdle              Motorola Mobility  2012-10-03
# 25293                 AR New York                Publicis Groupe  2012-12-04
# 24395                     iOnRoad                         Harman  2013-04-10
# 23768        Customer Value Group                          Xerox  2013-07-02
# 23036                     Cupoint                     RecargaPay  2013-10-01
# 17954                    Caugnate    Parametric Technology (PTC)  2015-01-01
# 17256    Ar-Jay Building Products           Ferguson Enterprises  2015-02-23
# 16223                 ARToolworks                          DAQRI  2015-05-13
# 16059                      Metaio                          Apple  2015-05-28
# 15237                       Yarly                Legacy Republic  2015-07-28
# 15049       AR Global Investments  Apollo Global Management, LLC  2015-08-06
# 15035              AR Metallizing                Nissha Printing  2015-08-07
# 14526                    Looksery                      Snap Inc.  2015-09-15
# 14375              Singapore Dine                      Foodpanda  2015-09-24
# 14011                 Pikato, Inc                     RetailNext  2015-10-13
# 13617                     Vuforia    Parametric Technology (PTC)  2015-11-03
# 13022               Teldar Travel                            HLD  2015-12-04
# 12720                 Drishya360s                     GirnarSoft  2015-12-20
# 11485                   Stag Arms             White Wolf Capital  2016-03-01
# 11314                  Covs Parts          Genuine Parts Company  2016-03-09
# 10297           cherrypicks alpha              NetDragon Websoft  2016-04-25
# 9933              ADS Reality Ltd                   Game Digital  2016-05-06
# 9613             Two Big Ears Ltd                       Facebook  2016-05-23
# 9454                 AR Packaging           CVC Capital Partners  2016-05-30
# 8267            GreenPowerMonitor                         DNV GL  2016-07-08
# 7670         Gallium Technologies            Ansonia Credit Data  2016-08-01
# 7365                    3DPhy.com                      PropTiger  2016-08-11
# 7046                      TrumpIt                        Wayfair  2016-08-30
# 4551          mwf-technology GmbH                           FARO  2016-12-12
# 4493          Greenlight Insights              M2 Advisory Group  2016-12-13
# 4304   KabaQ 3D Food Technologies              The Glimpse Group  2016-12-20
# 4178               Cimagine Media                      Snap Inc.  2016-12-25
# 4102                 LocateAR LLC              The Glimpse Group  2017-01-03
# 4046                    Engage PR            Witz Communications  2017-01-04
# 3219                   Amzon (HK)         Fireswirl Technologies  2017-02-03
# 1852                  XPerception                          Baidu  2017-04-13

# %%
'''
주제가 주어졌을때 다음을 시각화 한다.
1. 구글 트렌드
2. 투자
3. 인수

keyword: google trend keyword (사전에 keyword.csv 이름의 파일을 trends.google.com 에서 다운 받아야 함)
words: 회사 설명에서 다음과 같은 단어가 있으면 포함시킨다.
expand: 기본 단어외의 관련 단어를 추가할 것인가?
plot_all: 3가지가 모두 나온 하나의 그래프 외에, 개별 그래프 3가지를 따로 표시할 것인가?
start_date: 시작 시점
'''
color1 = 'black'
color2 = 'grey'
color3 = '#80bfff'
color4 = 'red'


def visualize(keyword, words, expand = False, plot_all = False, start_date = '2004-01', cumulative = False):
    fig = plt.figure()
    condition = 'first_funding_on'

    # 1. google web search trend data
    df_google_trend = pd.read_csv(trend_folder + keyword + '.csv', header = 1)  
    column1, column2 = df_google_trend.columns

    df_google_trend['google_count'] = df_google_trend[column2].groupby(df_google_trend[column1].str[:7]).transform('mean')
    df_google_trend['year-month'] = df_google_trend[column1].str[:7]
    df_google_trend = df_google_trend.loc[:,['year-month', 'google_count']]
    df_google_trend = df_google_trend.drop_duplicates()
    df_google_trend.columns = ['year-month', 'google_count']
    if plot_all:
        df_google_trend.plot(kind = 'line', x = df_google_trend['year-month'], figsize = (30, 8))

    # 2. google news trend data
    df_google_news_trend = pd.read_csv(trend_folder + keyword + '_news.csv', header = 1)  
    column1, column2 = df_google_news_trend.columns
    df_google_news_trend['google_news_count'] = df_google_news_trend[column2].groupby(df_google_news_trend[column1].str[:7]).transform('mean')

    df_google_news_trend['year-month'] = df_google_news_trend[column1].str[:7]
    df_google_news_trend = df_google_news_trend.loc[:,['year-month', 'google_news_count']]
    df_google_news_trend = df_google_news_trend.drop_duplicates()
    df_google_news_trend.columns = ['year-month', 'google_news_count']
    if plot_all:
        df_google_news_trend.plot(kind = 'line', x = df_google_news_trend['year-month'], figsize = (30, 8))

    # load required dataset
    if 'word2company' not in globals():
        print('loading word2company')
        global word2company
        word2company = pickle.load(open(util_folder + 'word2company.pickle'))
    if 'model' not in globals():
        print('loading word2vec model')
        global model
        model = gensim.models.word2vec.Word2Vec.load(util_folder + 'word2vec')

    # expand word set if necessary
    # train 된 word2vec 을 사용하여 관련도가 높은 단어들을 포함한다
    final_words = []
    if type(words) == str:
        words = [words]
    for word in words:
        if ' ' in word:
            word = word.replace(' ', '_')
        if expand:
            _words = model.most_similar(word)
            _words = [str(_word) for _word, sim in _words]
            final_words.extend(_words)
        final_words.append(word)
    final_words = list(set(final_words))

    # choose companies that have relevant words
    companies = []
    for word in final_words:
        _companies = word2company.get(word, [])
        companies.extend(_companies)
    companies = list(set(companies))

    if not cumulative: # just to print once
        print('Google Trend: {}\n Companies with keywords:{}'.format(keyword, final_words))

    # 회사를 시기 별로 정리한다
    # 3. funding
    df_companies = df_organizations[df_organizations['uuid'].isin(companies)]
    df = pd.DataFrame()
    df['date'] = df_companies["first_funding_on"]
    df = df[~df['date'].isnull()]
    df['year-month'] = df['date'].str[:7]
    funding = df.groupby(df['year-month']).size().reset_index()
    funding.columns = ['year-month', 'funding_count']
    funding = funding[funding['year-month'] >= start_date]
    if plot_all:
        funding.plot(kind = 'bar', x = funding['year-month'], figsize = (30, 8))


    df_merged = pd.merge(df_google_trend, funding, on = 'year-month', how = 'outer')
    df_merged = df_merged.merge(df_google_news_trend, on = 'year-month', how = 'outer')

    # 4. acquisition
    df = df_acq[df_acq['acquiree_uuid'].isin(companies)]
    print(df[['acquiree_name', 'acquirer_name', 'acquired_on']].sort_values('acquired_on'))
    df = df.loc[:,['acquired_on']]
    df['year-month'] = df['acquired_on'].str[:7]
    acq = df.groupby(df['year-month']).size().reset_index()
    acq.columns = ['year-month', 'acq_count']
    acq = acq[acq['year-month'] >= start_date]

    if plot_all:
        acq.plot(kind = 'bar', x = acq['year-month'], figsize = (30, 8))

    df_merged = pd.merge(df_merged, acq, on = 'year-month', how = 'outer')
    df_merged = df_merged.sort_values(['year-month'])    
    df_merged['year'] = np.where(df_merged['year-month'].str[5:7] == '01', df_merged['year-month'].str[:4], '')

    if cumulative:
        df_merged['funding_count'] = df_merged['funding_count'].fillna(0)
        df_merged['funding_count'] = df_merged['funding_count'].cumsum()

        div_by = 100.0 / (df_merged['funding_count'].max() + 1)
        df_merged['google_count'] /= div_by
        df_merged['google_news_count'] /= div_by

        df_merged['acq_count'] = df_merged['acq_count'].fillna(0)
        df_merged['acq_count'] = df_merged['acq_count'].cumsum()
        df_merged['acq_count'] /= ((df_merged['acq_count'].max()) / (df_merged['funding_count'].max() + 1))

        df_merged[['year-month', 'google_count', 'google_news_count', 'funding_count', 'acq_count']].plot(x = df_merged['year'], linestyle = '-', color = [color1, color2, color3, color4], fontsize = 25, figsize = (30, 8)).legend(loc = 2, fontsize = 20, labels = ['google web search trend', 'google news trend', '# funding',  '# M&A',])

    else:        
        div_by = 100.0 / (df_merged['funding_count'].max() + 1)
        df_merged['google_count'] /= div_by
        df_merged['google_news_count'] /= div_by


        ax = df_merged[['year-month', 'google_count', 'google_news_count']].plot(x = df_merged['year'], linestyle = '-', color = [color1, color2])
        df_merged[['year-month', 'funding_count', 'acq_count']].plot(x = df_merged['year'], kind = 'bar', rot = 0, ax = ax, fontsize = 25, figsize = (30, 8), color = [color3, color4]).legend(loc = 2, fontsize = 20, labels = ['google web search trend', 'google news trend', '# funding', '# M&A'])

# %%
visualize_all('augmented_reality', ['augmented_reality', 'ar'], expand = False, plot_all = False)
# Out:
# Google Trend: augmented_reality
#  Companies with keywords:['ar', 'augmented_reality']
#                     acquiree_name                  acquirer_name acquired_on
# 37398                  NetRegulus    Parametric Technology (PTC)  2007-09-24
# 35782              Arius Research                          Roche  2008-07-22
# 27479                        Vibe                      Betaworks  2012-02-23
# 26270                   Bixti.com                           Elo7  2012-07-30
# 25744                     Viewdle              Motorola Mobility  2012-10-03
# 25293                 AR New York                Publicis Groupe  2012-12-04
# 24395                     iOnRoad                         Harman  2013-04-10
# 23768        Customer Value Group                          Xerox  2013-07-02
# 23036                     Cupoint                     RecargaPay  2013-10-01
# 17954                    Caugnate    Parametric Technology (PTC)  2015-01-01
# 17256    Ar-Jay Building Products           Ferguson Enterprises  2015-02-23
# 16223                 ARToolworks                          DAQRI  2015-05-13
# 16059                      Metaio                          Apple  2015-05-28
# 15237                       Yarly                Legacy Republic  2015-07-28
# 15049       AR Global Investments  Apollo Global Management, LLC  2015-08-06
# 15035              AR Metallizing                Nissha Printing  2015-08-07
# 14526                    Looksery                      Snap Inc.  2015-09-15
# 14375              Singapore Dine                      Foodpanda  2015-09-24
# 7365                    3DPhy.com                      PropTiger  2016-08-11
# 7046                      TrumpIt                        Wayfair  2016-08-30
# 4551          mwf-technology GmbH                           FARO  2016-12-12
# 4493          Greenlight Insights              M2 Advisory Group  2016-12-13
# 4304   KabaQ 3D Food Technologies              The Glimpse Group  2016-12-20
# 4178               Cimagine Media                      Snap Inc.  2016-12-25
# 4102                 LocateAR LLC              The Glimpse Group  2017-01-03
# 4046                    Engage PR            Witz Communications  2017-01-04
# 3219                   Amzon (HK)         Fireswirl Technologies  2017-02-03
# 1852                  XPerception                          Baidu  2017-04-13

# %%
visualize_all('wearable', ['wearable', 'wearables', 'smartwatch', 'smart_glasses', 'wearable_device', 'wrist_worn', 'wearable_sensor', 'wearable_devices', 'wearable', 'wearable_tech', 'wearable_technology'], plot_all = False)
# Out:
# Google Trend: wearable
#  Companies with keywords:['wearable_tech', 'wearables', 'smartwatch', 'smart_glasses', 'wearable_device', 'wrist_worn', 'wearable_sensor', 'wearable_devices', 'wearable', 'wearable_technology']
#                     acquiree_name                  acquirer_name acquired_on
# 46305                 Club Monaco       Ralph Lauren Corporation  1999-03-02
# 41807                  Dspfactory              AMI Semiconductor  2004-11-01
# 40681                     Itronix               General Dynamics  2005-08-03
# 35037                  Textronics                         Adidas  2008-12-08
# 31643             Anaconda Sports                        Genesco  2010-09-07
# 31574        The ERGObaby Carrier   Compass Diversified Holdings  2010-09-17
# 30149                  C2O Mobile                    BrightPoint  2011-03-22
# 29308                 AppMade Lab                      Provectus  2011-07-01
# 27070                Camera Corps                    Vitec Group  2012-04-13
# 26265               Tonalite B.V.                    Plantronics  2012-07-31
# 24384                  Fibers.com                     BlueCotton  2013-04-11
# 24298                   BodyMedia                        Jawbone  2013-04-30
# 23834  Tibion Bionic Technologies                         AlterG  2013-06-27
# 23660                  PrimeSense                          Apple  2013-07-18
# 23334                   WIMM Labs                         Google  2013-08-31
# 22683               Bottle Rocket                            WPP  2013-11-08
# 21678            Skyhook Wireless                   TruePosition  2014-02-19
# 21219          ZXY Sport Tracking                     ChyronHego  2014-04-06
# 18274                     Visijax  Wearable Technologies Limited  2014-12-05
# 18269    ICE ID Solutions Limited  Wearable Technologies Limited  2014-12-05
# 18125               Vergence Labs                      Snap Inc.  2014-12-17
# 17705         Composyt Light Labs                          Intel  2015-01-21
# 17026                        Kili                         Square  2015-03-11
# 15989            Clothing Plus Oy                          Jabil  2015-06-01
# 14609                    CogniVue        Freescale Semiconductor  2015-09-10
# 14317         PA Consulting Group              The Carlyle Group  2015-09-29
# 13861                     SanDisk   Western Digital Technologies  2015-10-21
# 13718                   Binocular                        Blippar  2015-10-29
# 13431            Misfit Wearables                         Fossil  2015-11-12
# 13076           ONtheGO Platforms                         Atheer  2015-12-02
# 12034                 Flyby Media                          Apple  2016-01-29
# 11793              CareKit Health            Moseda Technologies  2016-02-10
# 9683                         Coin                         Fitbit  2016-05-18
# 7617                News Republic                 Cheetah Mobile  2016-08-02
# 6942           Dymedex Consulting            Navigant Consulting  2016-09-01
# 7617                News Republic                 Cheetah Mobile  2016-08-02
# 6942           Dymedex Consulting            Navigant Consulting  2016-09-01
# 6858                     Movidius                          Intel  2016-09-06
# 5649                   Eyefluence                         Google  2016-10-24
# 5571           NXP Semiconductors                       Qualcomm  2016-10-27
# 5137                    CloudMade                          Valeo  2016-11-15
# 4740                  Tiny Hearts                        Shopify  2016-12-05
# 4692       Newgen Distribution AB               CMS Distribution  2016-12-06
# 4530      Cronologics Corporation                         Google  2016-12-12
# 4058                         Jiff               Castlight Health  2017-01-04
# 3904                 Vector Watch                         Fitbit  2017-01-10
# 3852                   Tazer Wear              Innovo Technology  2017-01-11
# 2949                        Idean                Capgemini Group  2017-02-16
# 2786                       Pocket                        Mozilla  2017-02-27
# 2732                 Olio Devices      Flextronics International  2017-03-01
# 2442            Monica Healthcare                  GE Healthcare  2017-03-15
# 2363                3ti Solutions                   Mirum Agency  2017-03-20
# 1180    Cupola Technology Pvt Ltd    Happiest Minds Technolgoies  2017-05-11
# 916                       Fit Pay                         NXT-ID  2017-05-24
# 847                        Stanfy                  Intellectsoft  2017-05-30
# 558                     GreatCall                           GTCR  2017-06-07
# 514                       Gait Up                       MindMaze  2017-06-08

# %%
visualize_all('iot', 'iot', expand = False, plot_all = False)
# Out:
# Google Trend: iot
#  Companies with keywords:['iot']
#                                 acquiree_name  \
# 43420                                   Azlan
# 39199                               Qualphone
# 37398                              NetRegulus
# 31268                                   Stuzo
# 26214                              SpringSoft
# 21678                        Skyhook Wireless
# 21398                        P-Device Systems
# 20497                                Viryanet
# 19036                                  Radius
# 18366                                 Octoblu
# 17725                       Red Bend Software
# 17684                          Annapurna Labs
# 17430                          Wireless Logic
# 16994                                2lemetry
# 16934                   Vitesse Semiconductor
# 16904                         Coversant, Inc.
# 16812                         Feeney Wireless
# 16402                      LightMiner Systems
# 15937                             TierConnect
# 15202                          Sansa Security
# 14822                              SeeControl
# 14358                             AppCarousel
# 13789                               ParStream
# 12346                                  Emmoco
# 12187                       Unikernel Systems
# 11935                          Jasper @ Cisco
# 11594                               BlueKloud
# 10634                              Skygistics
# 10466                  GreenPeak Technologies
# 10344                        Device Authority
# 10191        Broadcom's Wireless IoT Business
# 8896                               Connode AB
# 8793                      FalconX Accelerator
# 8792                                  Ericpol
# 8561                     whatever mobile GmbH
# 8292                                  DGLogik
# 7792                L-Com Global Connectivity
# 7246                                Dojo Labs
# 7204   Extensys - Internet of Things Business
# 6711                            Maven Systems
# 6284                                 PLAT.ONE
# 6177                                  Micrium
# 5277                         Machina Research
# 2901                                 Mistbase
# 2680                                    Loopd
# 2465                          Meerchant, Inc.
# 2363                            3ti Solutions
# 1743                                   InLogg
# 1180                Cupola Technology Pvt Ltd
# 924                                  MODELiiS
# 847                                    Stanfy
# 819                                  Carriots
# 662                              Prosa S.r.l.
# 369                        Weather Telematics
# 248                                codebender
# 220                              LCC Pakistan
#
#                          acquirer_name acquired_on
# 43420                        Tech Data  2003-03-31
# 39199                         Qualcomm  2006-08-21
# 8792                                  Ericpol
# 8561                     whatever mobile GmbH
# 8292                                  DGLogik
# 7792                L-Com Global Connectivity
# 7246                                Dojo Labs
# 7204   Extensys - Internet of Things Business
# 6711                            Maven Systems
# 6284                                 PLAT.ONE
# 6177                                  Micrium
# 5277                         Machina Research
# 2901                                 Mistbase
# 2680                                    Loopd
# 2465                          Meerchant, Inc.
# 2363                            3ti Solutions
# 1743                                   InLogg
# 1180                Cupola Technology Pvt Ltd
# 924                                  MODELiiS
# 847                                    Stanfy
# 819                                  Carriots
# 662                              Prosa S.r.l.
# 369                        Weather Telematics
# 248                                codebender
# 220                              LCC Pakistan
#
#                          acquirer_name acquired_on
# 43420                        Tech Data  2003-03-31
# 39199                         Qualcomm  2006-08-21
# 37398      Parametric Technology (PTC)  2007-09-24
# 31268                     Dachis Group  2010-11-01
# 26214                         Synopsys  2012-08-03
# 21678                     TruePosition  2014-02-19
# 21398                           Altiux  2014-03-19
# 20497                          Verisae  2014-06-10
# 19036                           Luxoft  2014-10-07
# 18366                   Citrix Systems  2014-12-01
# 17725  Harman International Industries  2015-01-20
# 17684                           Amazon  2015-01-22
# 17430             CVC Capital Partners  2015-02-10
# 16994                           Amazon  2015-03-12
# 16934                        Microsemi  2015-03-18
# 16904             Ubiquity Corporation  2015-03-20
# 16812                 Novatel Wireless  2015-03-30
# 16402                          Inpixon  2015-04-30
# 15937                            Mojix  2015-06-04
# 15202                              ARM  2015-07-30
# 14822                         Autodesk  2015-08-27
# 14358                        AppDirect  2015-09-24
# 13789                            Cisco  2015-10-26
# 12346                       Shelfbucks  2016-01-12
# 12187                           Docker  2016-01-21
# 11935                            Cisco  2016-02-03
# 11594                         Advantix  2016-02-23
# 10634                          ORBCOMM  2016-04-12
# 10466                            Qorvo  2016-04-18
# 10344                       Cryptosoft  2016-04-21
# 10191                          Cypress  2016-04-28
# 8896               Cyan Technology Ltd  2016-06-16
# 8793                           BaySand  2016-06-21
# 8792                          Ericsson  2016-06-21
# 8561                     Link Mobility  2016-06-30
# 8292                     Acuity Brands  2016-07-07
# 7792              Infinite RF Holdings  2016-07-27
# 7246                         BullGuard  2016-08-17
# 7204                          CompuCom  2016-08-19
# 6711                           MosChip  2016-09-12
# 6284                               SAP  2016-09-28
# 6177              Silicon Laboratories  2016-10-03
# 5277                           Gartner  2016-11-09
# 2901                               ARM  2017-02-20
# 2680                          etouches  2017-03-02
# 2465                          ShopKeep  2017-03-14
# 2363                      Mirum Agency  2017-03-20
# 1743                            Myntra  2017-04-19
# 1180       Happiest Minds Technolgoies  2017-05-11
# 924                 Altair Engineering  2017-05-24
# 847                      Intellectsoft  2017-05-30
# 819                 Altair Engineering  2017-05-30
# 662                   Danfoss Ventures  2017-06-05
# 369                 Internet of Things  2017-06-15
# 248                       Codeanywhere  2017-06-20
# 220                           TalkPool  2017-06-21

# %%
visualize_all('bitcoin', 'bitcoin', expand = True, plot_all = False)
# Out:
# Google Trend: bitcoin
#  Companies with keywords:['bitcoin']
#                                 acquiree_name  \
# 23089                               Braintree
# 22235                               ZeroBlock
# 18381                                yBitcoin
# 18133                     Bongo International
# 17702                        Bitcoin Magazine
# 16663                                Cavirtex
# 16343                          Bitcoin Brains
# 15685                           Bits Of Proof
# 15152                           Coin Republic
# 14979                                Coinzone
# 14502  Unisend Latinamerican Bitcoin Exchange
# 14222                               Coin Fire
# 12316                                CoinDesk
# 12265                              Coinsetter
# 12264                                Cavirtex
# 9185                                 BitQuick
# 9001                             XBT Provider
# 7956                               BlockTrail
# 4492                                  Glidera
# 2291                          The LTB Network
#
#                                  acquirer_name acquired_on
# 23089                                   PayPal  2013-09-26
# 22235                               Blockchain  2013-12-24
# 18381                                BTC Media  2014-12-01
# 18133                                    FedEx  2014-12-16
# 17702                                BTC Media  2015-01-21
# 16663                               Coinsetter  2015-04-08
# 16343                              BitNational  2015-05-04
# 15685                            Digital Asset  2015-06-25
# 15152                                    meXBT  2015-08-01
# 14979                              Coinify ApS  2015-08-12
# 14502                                    Ripio  2015-09-16
# 14222                              99 Bitcoins  2015-10-01
# 12316                   Digital Currency Group  2016-01-13
# 12265                  Kraken Bitcoin Exchange  2016-01-17
# 12264                  Kraken Bitcoin Exchange  2016-01-17
# 9185                            Athena Bitcoin  2016-06-06
# 9001   Global Advisors Bitcoin Investment Fund  2016-06-14
# 7956                                   Bitmain  2016-07-20
# 4492                   Kraken Bitcoin Exchange  2016-12-13
# 2291                                 BTC Media  2017-03-24
#                                 acquiree_name  \
# 23089                               Braintree
# 22235                               ZeroBlock
# 18381                                yBitcoin
# 18133                     Bongo International
# 17702                        Bitcoin Magazine
# 16663                                Cavirtex
# 16343                          Bitcoin Brains
# 15685                           Bits Of Proof
# 15152                           Coin Republic
# 14979                                Coinzone
# 14502  Unisend Latinamerican Bitcoin Exchange
# 14222                               Coin Fire
# 12316                                CoinDesk
# 12265                              Coinsetter
# 12264                                Cavirtex
# 9185                                 BitQuick
# 9001                             XBT Provider
# 7956                               BlockTrail
# 4492                                  Glidera
# 2291                          The LTB Network
#
#                                  acquirer_name acquired_on
# 23089                                   PayPal  2013-09-26
# 22235                               Blockchain  2013-12-24
# 18381                                BTC Media  2014-12-01
# 18133                                    FedEx  2014-12-16
# 17702                                BTC Media  2015-01-21
# 16663                               Coinsetter  2015-04-08
# 16343                              BitNational  2015-05-04
# 15685                            Digital Asset  2015-06-25
# 15152                                    meXBT  2015-08-01
# 14979                              Coinify ApS  2015-08-12
# 14502                                    Ripio  2015-09-16
# 14222                              99 Bitcoins  2015-10-01
# 12316                   Digital Currency Group  2016-01-13
# 12265                  Kraken Bitcoin Exchange  2016-01-17
# 12264                  Kraken Bitcoin Exchange  2016-01-17
# 9185                            Athena Bitcoin  2016-06-06
# 9001   Global Advisors Bitcoin Investment Fund  2016-06-14
# 7956                                   Bitmain  2016-07-20
# 4492                   Kraken Bitcoin Exchange  2016-12-13
# 2291                                 BTC Media  2017-03-24

# %%
visualize_all('blockchain', 'blockchain', expand = True, plot_all = False)
# Out:
# Google Trend: blockchain
#  Companies with keywords:['blockchain']
#                       acquiree_name                           acquirer_name  \
# 18381                      yBitcoin                               BTC Media
# 15545  Blockchain Technologies Corp                    Global Arena Holding
# 13719                 Blockstack.io                           Digital Asset
# 9106                Canaan Creative  Shandong Luyitong Intelligent Electric
# 3463                      KreateIoT                             Health Wizz
# 3409                      Lawnmower                                CoinDesk
# 2794                           Skry                                    Bloq
# 2056                        Remitsy                                    Wyre
# 1871                         nChain    PI High Tech Private Equity SuB-Fund
# 1009             Proof of Existence                         Canaan Creative
#
#       acquired_on
# 18381  2014-12-01
# 15545  2015-07-02
# 13719  2015-10-29
# 9106   2016-06-08
# 3463   2017-01-26
# 3409   2017-01-30
# 2794   2017-02-27
# 2056   2017-04-04
# 1871   2017-04-12
# 1009   2017-05-20
#                       acquiree_name                           acquirer_name  \
# 18381                      yBitcoin                               BTC Media
# 15545  Blockchain Technologies Corp                    Global Arena Holding
# 13719                 Blockstack.io                           Digital Asset
# 9106                Canaan Creative  Shandong Luyitong Intelligent Electric
# 3463                      KreateIoT                             Health Wizz
# 3409                      Lawnmower                                CoinDesk
# 2794                           Skry                                    Bloq
# 2056                        Remitsy                                    Wyre
# 1871                         nChain    PI High Tech Private Equity SuB-Fund
# 1009             Proof of Existence                         Canaan Creative
#
#       acquired_on
# 18381  2014-12-01
# 15545  2015-07-02
# 13719  2015-10-29
# 9106   2016-06-08
# 3463   2017-01-26
# 3409   2017-01-30
# 2794   2017-02-27
# 2056   2017-04-04
# 1871   2017-04-12
# 1009   2017-05-20

# %%
visualize_all('deep_learning', 'deep learning', expand = False, plot_all = False)
# Out:
# Google Trend: deep_learning
#  Companies with keywords:['deep_learning']
#                         acquiree_name         acquirer_name acquired_on
# 35668                      Parascript  Authentidate Holding  2008-08-06
# 18810                  Dark Blue Labs                Google  2014-10-23
# 18817                  Vision Factory                Google  2014-10-23
# 17097                      AlchemyAPI                   IBM  2015-03-04
# 14158                       Perceptio                 Apple  2015-10-05
# 13124                          Orbeus                Amazon  2015-12-01
# 7448                          Nervana                 Intel  2016-08-09
# 7298                            SAIPS    Ford Motor Company  2016-08-16
# 6269   Wireless System Integration AB             Allgon AB  2016-09-29
# 3777                          Maluuba             Microsoft  2017-01-13
# 2209                       Siftr Labs            APUS Group  2017-03-29
# 2024                     ViDi Systems                Cognex  2017-04-05
# 1079                           niland               Spotify  2017-05-17
#                         acquiree_name         acquirer_name acquired_on
# 35668                      Parascript  Authentidate Holding  2008-08-06
# 18810                  Dark Blue Labs                Google  2014-10-23
# 18817                  Vision Factory                Google  2014-10-23
# 17097                      AlchemyAPI                   IBM  2015-03-04
# 14158                       Perceptio                 Apple  2015-10-05
# 13124                          Orbeus                Amazon  2015-12-01
# 7448                          Nervana                 Intel  2016-08-09
# 7298                            SAIPS    Ford Motor Company  2016-08-16
# 6269   Wireless System Integration AB             Allgon AB  2016-09-29
# 3777                          Maluuba             Microsoft  2017-01-13
# 2209                       Siftr Labs            APUS Group  2017-03-29
# 2024                     ViDi Systems                Cognex  2017-04-05
# 1079                           niland               Spotify  2017-05-17

# %%
visualize_all('drone', 'drone', expand = True, plot_all = False)
# Out:
# Google Trend: drone
#  Companies with keywords:['drone']
#                 acquiree_name     acquirer_name acquired_on
# 13718               Binocular           Blippar  2015-10-29
# 12528  Ascending Technologies             Intel  2016-01-04
# 5511            Erle Robotics         ACUTRONIC  2016-10-31
# 5036         Vantage Vertical  The Falcon Group  2016-11-21
# 2967                  Skyward  Verizon Wireless  2017-02-16
#                 acquiree_name     acquirer_name acquired_on
# 13718               Binocular           Blippar  2015-10-29
# 12528  Ascending Technologies             Intel  2016-01-04
# 5511            Erle Robotics         ACUTRONIC  2016-10-31
# 5036         Vantage Vertical  The Falcon Group  2016-11-21
# 2967                  Skyward  Verizon Wireless  2017-02-16

# %%
visualize_all('social_media', 'social_media', expand = False, plot_all = False)
# Out:
# Google Trend: social_media
#  Companies with keywords:['social_media']
#                                acquiree_name               acquirer_name  \
# 46547                         Submit Express                linkexchange
# 46307                         Argon Networks                  Siemens AG
# 45893                                   Cone               Omnicom Group
# 44858                              Webtrends                       NetIQ
# 41300              J.D. Power and Associates       McGraw Hill Financial
# 41227                              Webtrends          Francisco Partners
# 40737                               Blockdot               Media General
# 39759                            Mobile-Mind                   Worldcell
# 39535                               Salesnet       RightNow Technologies
# 39152                             Hipcricket       NeoMedia Technologies
# 39147                             Via Caroli             IMPOWER FINANCE
# 38674                        Quilter Cheviot                   Citigroup
# 38640                             DigitasLBi             Publicis Groupe
# 38550                   New Media Strategies        Meredith Corporation
# 38174                              Advaliant                  MediaTrust
# 38166                          Reprise Media           Interpublic Group
# 37706                        Mediabistro.com    JupiterMedia Corporation
# 37366                                Traffix                    Atrinsic
# 37025                             stylediary                   Stylehive
# 36793                                   Sway                 CornerWorld
# 36778                                 Snocap                       imeem
# 36614                                  Pluck                  Leaf Group
# 36496                                 Umbria   J.D. Power and Associates
# 36230                          Absolute Punk             SpinMedia Group
# 35983                              UGENmedia                      Vitrue
# 35832                               OnlyWire                   Snipitron
# 35817                      Chirp Interactive                 thePlatform
# 35588                            Blogcritics                  Technorati
# 35383                 Clear Blue Interactive                   Affluence
# 35122                          Ripple6, Inc.              Gannett Co Inc
# ...                                      ...                         ...
# 2684                        My Action Replay                      CricHQ
# 2619                           Legend Engage         Four Communications
# 2618                                      L2                     Gartner
# 2479                                    WTF1                Car Throttle
# 2453                                AGENCE79                 Havas Group
# 2421                         uFluencer Group                   Gushcloud
# 2408                                ModCloth                         Jet
# 2341                            Glue PR Ltd.            W Communications
# 2238                             Upplication   Mobusi Mobile Advertising
# 2218                   Bulletin Intelligence                      Cision
# 2147                         Hallam Internet                   BigSpring
# 2099                                   JSH&A  L.C. Williams & Associates
# 2073                     Ying Communications               Finn Partners
# 2063                     Turnstyle Solutions                        Yelp
# 1809                           Towers Design             Zest The Agency
# 1728                               Covercake                     Spindle
# 1605                            Sitening LLC                   TapClicks
# 1505                           Jive Software              Aurea Software
# 1497                           Court Chatter                     LawNewz
# 1477                           Web Decisions                    Deloitte
# 1349                                  Lissly                    Notified
# 1292                         REV Asia Berhad          Media Prima Berhad
# 1034                          Crispy Content           Serviceplan Group
# 1027                         Are You a Human             Distil Networks
# 972                                  TapWalk                    RaceMenu
# 949                            Digital Roots    Interactions Corporation
# 729                     EMAP Publishing (UK)    Metropolis International
# 618                                 Tidemark          Longview Solutions
# 433                                 Ubiquity                      Qrious
# 314    Social Media Broadcasts (SMB) Limited                   Meltwater
#
#       acquired_on
# 46547  1998-06-28
# 46307  1999-03-01
# 45893  1999-12-01
# 44858  2001-01-17
# 41300  2005-03-08
# 41227  2005-03-29
# 40737  2005-07-23
# 39759  2006-03-24
# 39535  2006-05-22
# 39152  2006-08-31
# 39147  2006-09-01
# 38674  2006-12-13
# 38640  2006-12-20
# 38550  2007-01-10
# 38174  2007-04-05
# 38166  2007-04-11
# 37706  2007-07-18
# 37366  2007-10-01
# 37025  2007-12-11
# 36793  2008-01-31
# 36778  2008-02-01
# 36614  2008-03-04
# 36496  2008-04-01
# 36230  2008-05-05
# 35983  2008-06-25
# 35832  2008-07-15
# 35817  2008-07-16
# 35588  2008-08-26
# 35383  2008-09-29
# 35122  2008-11-14
# ...           ...
# 2684   2017-03-02
# 2619   2017-03-06
# 2618   2017-03-06
# 2479   2017-03-14
# 2453   2017-03-14
# 2421   2017-03-16
# 2408   2017-03-16
# 2341   2017-03-21
# 2238   2017-03-28
# 2218   2017-03-28
# 2147   2017-03-31
# 2099   2017-04-03
# 2073   2017-04-04
# 2063   2017-04-04
# 1809   2017-04-15
# 1728   2017-04-19
# 1605   2017-04-26
# 1505   2017-05-01
# 1497   2017-05-01
# 1477   2017-05-02
# 1349   2017-05-05
# 1292   2017-05-09
# 1034   2017-05-18
# 1027   2017-05-18
# 972    2017-05-23
# 949    2017-05-23
# 729    2017-06-01
# 618    2017-06-06
# 433    2017-06-13
# 314    2017-06-19
#
# [542 rows x 3 columns]
#                                acquiree_name               acquirer_name  \
# 46547                         Submit Express                linkexchange
# 46307                         Argon Networks                  Siemens AG
# 45893                                   Cone               Omnicom Group
# 44858                              Webtrends                       NetIQ
# 41300              J.D. Power and Associates       McGraw Hill Financial
# 41227                              Webtrends          Francisco Partners
# 40737                               Blockdot               Media General
# 39759                            Mobile-Mind                   Worldcell
# 39535                               Salesnet       RightNow Technologies
# 39152                             Hipcricket       NeoMedia Technologies
# 39147                             Via Caroli             IMPOWER FINANCE
# 38674                        Quilter Cheviot                   Citigroup
# 38640                             DigitasLBi             Publicis Groupe
# 38550                   New Media Strategies        Meredith Corporation
# 38174                              Advaliant                  MediaTrust
# 38166                          Reprise Media           Interpublic Group
# 37706                        Mediabistro.com    JupiterMedia Corporation
# 37366                                Traffix                    Atrinsic
# 37025                             stylediary                   Stylehive
# 36793                                   Sway                 CornerWorld
# 36778                                 Snocap                       imeem
# 36614                                  Pluck                  Leaf Group
# 36496                                 Umbria   J.D. Power and Associates
# 36230                          Absolute Punk             SpinMedia Group
