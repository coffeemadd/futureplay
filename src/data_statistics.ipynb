# %%
import pandas as pd

# %%
# load data
data_folder = '../data/csv_export/'
util_folder = '../util/'
df_organizations = pd.read_csv(data_folder + 'organizations.csv'.format(data_folder), dtype={'first_funding_on': str, 'last_funding_on':str})
df_description = pd.read_csv(data_folder + 'organization_descriptions.csv')
df_funding_rounds = pd.read_csv(data_folder + 'funding_rounds.csv')
df_funds = pd.read_csv(data_folder + 'funds.csv')
df_investments = pd.read_csv(data_folder + 'investments.csv')
df_acq = pd.read_csv(data_folder + 'acquisitions.csv')
df_ipo = pd.read_csv(data_folder + 'ipos.csv')
df_people = pd.read_csv(data_folder + 'people.csv')
df_degrees = pd.read_csv(data_folder + 'degrees.csv')
df_investors = pd.read_csv(data_folder + 'investors.csv')
df_country_code = pd.read_csv(util_folder + 'country_code.csv', delimiter = '\t')

# %%
df_organizations.columns
# Out:
# Index([u'company_name', u'primary_role', u'permalink', u'domain',
#        u'homepage_url', u'country_code', u'state_code', u'region', u'city',
#        u'zipcode', u'address', u'status', u'short_description',
#        u'category_list', u'category_group_list', u'funding_rounds',
#        u'funding_total_usd', u'founded_on', u'first_funding_on',
#        u'last_funding_on', u'closed_on', u'employee_count', u'email', u'phone',
#        u'facebook_url', u'linkedin_url', u'cb_url', u'logo_url',
#        u'profile_image_url', u'twitter_url', u'alias', u'uuid', u'created_at',
#        u'updated_at'],
#       dtype='object')

# %%
df_organizations['founded_on'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-faa03461ea9b> in <module>()
# ----> 1 df_organizations['founded_on'].plot()
#
# /Users/joonheekim/Projects/futureplay/venv/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2441                            colormap=colormap, table=table, yerr=yerr,
#    2442                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2443                            **kwds)
#    2444     __call__.__doc__ = plot_series.__doc__
#    2445
#
# /Users/joonheekim/Projects/futureplay/venv/lib/python2.7/site-packages/pandas/plotting/_core.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1882                  yerr=yerr, xerr=xerr,
#    1883                  label=label, secondary_y=secondary_y,
# -> 1884                  **kwds)
#    1885
#    1886
#
# /Users/joonheekim/Projects/futureplay/venv/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1682         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1683
# -> 1684     plot_obj.generate()
#    1685     plot_obj.draw()
#    1686     return plot_obj.result
#
# /Users/joonheekim/Projects/futureplay/venv/lib/python2.7/site-packages/pandas/plotting/_core.pyc in generate(self)
#     236     def generate(self):
#     237         self._args_adjust()
# --> 238         self._compute_plot_data()
#     239         self._setup_subplots()
#     240         self._make_plot()
#
# /Users/joonheekim/Projects/futureplay/venv/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _compute_plot_data(self)
#     345         if is_empty:
#     346             raise TypeError('Empty {0!r}: no numeric data to '
# --> 347                             'plot'.format(numeric_data.__class__.__name__))
#     348
#     349         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
# df_organizations.sort_values('founded_on', ascending = False)[['company_name', 'category_list', 'funding_rounds', 'employee_count', 'founded_on']]
df_organizations[['company_name', 'category_list', 'funding_rounds', 'employee_count', 'founded_on']]
# Out:
#                                              company_name  \
# 0                                                   Intel
# 1                                               Intercomp
# 2                                               Microsoft
# 3                                                  Compaq
# 4                                       BDS, Incorporated
# 5                                Toyota Motor Corporation
# 6                                                    Ikro
# 7                                         Electronic Arts
# 8                                                Indelsul
# 9                                       Laboratórios Noli
# 10                                      Linear Technology
# 11                                                Polimax
# 12                                                Knoware
# 13                                   Morcom International
# 14                                              Mixertech
# 15                                                Promega
# 16                                    World Markets Group
# 17                                                Aeromot
# 18                                                Digitel
# 19                                            Curtume Erê
# 20                                      FSI International
# 21                                 Employee Benefit Plans
# 22                Medaphis Physician Services Corporation
# 23                                                Telebit
# 24                                 Chips and Technologies
# 25                                                  Cisco
# 26                                Integrated Systems Inc.
# 27                                              NHK World
# 28                                          Clean Harbors
# 29                                              Microinox
# ...                                                   ...
# 520378                               Zyxware Technologies
# 520379                                   Zyzzyva Magazine
# 520380                                            ZZAlpha
# 520381                                            Zzappit
# 520382                                      ZZ Best Games
# 520383                                         ZZ Capital
# 520384                                          ZZ Driggs
# 520385                                                ZZJ
# 520386                                        ZZoom Media
# 520387                                      zZounds Music
# 520388                     ZZ Transportation and Services
# 520389                                            ZZ Wolf
# 520390                                 ZZYX Entertainment
# 520391                                       ZZZleepandGo
# 520392                                             ZΛDΛTΛ
# 520393                                              Þoran
# 520394                                              μ-Tec
# 520395                                        ΤechΜaniacs
# 520396                                              Вомос
# 520397                                               СDEK
# 520398                                      Chinatoursnet
# 520399                                  Flickdeal Limited
# 520400  办加州大学圣地亚哥分校【Q微405665716】办美国UCSD文凭/毕业证成绩单/真实学历认...
# 520401  办加州大学戴维斯分校【Q微405665716】办美国UCD文凭/毕业证成绩单/真实学历认证|...
# 520402  办加州州立理工大学波莫那分校【Q微405665716】办美国加州理工文凭/毕业证成绩单/真实...
# 520403  办威斯康星大学麦迪逊分校【Q微405665716】办美国UWM文凭/毕业证成绩单/真实学历认...
# 520404  办普渡大学【Q微405665716】办美国PU文凭/毕业证成绩单/真实学历认证|（Purdu...
# 520405  办纽约大学【Q微405665716】办美国NYU文凭/毕业证成绩单/真实学历认证|（ New...
# 520406  办芝加哥大学【Q微405665716】办美国UChicago文凭/毕业证成绩单/真实学历认证...
# 520407  办麻省理工学院【Q微405665716】办美国MIT文凭/毕业证成绩单/真实学历认证|（Ma...
#
#                                             category_list  funding_rounds  \
# 0       hardware|manufacturing|product design|semicond...               1
# 1                                       hardware|software               1
# 2       cloud computing|collaboration|developer tools|...               1
# 3                hardware|information technology|software               1
# 4                    computer|government|service industry               1
# 5                        automotive|mobile|transportation               1
# 6                                automotive|manufacturing               1
# 7                    computer|video games|web development               2
# 8                                                     NaN               1
# 9                                      medical|veterinary               1
# 10                   manufacturing|semiconductor|software               3
# 11                                                    NaN               1
# 12                                        gaming|pc games               1
# 13      communication hardware|communications infrastr...               1
# 14                                                    NaN               1
# 15                  journalism|life science|manufacturing               1
# 16                                                    NaN               1
# 17                            aerospace|national security               1
# 18      big data|data visualization|information techno...               1
# 19                consumer goods|industrial|manufacturing               1
# 20                  manufacturing|marketing|semiconductor               1
# 21            employee benefits|human resources|insurance               1
# 22                                            health care               1
# 23                                          manufacturing               1
# 24                electronics|manufacturing|semiconductor               1
# 25      communications infrastructure|enterprise softw...               1
# 26                              embedded systems|software               1
# 27                                                   news               1
# 28                            cleantech|energy|industrial               1
# 29            advanced materials|automotive|manufacturing               1
# ...                                                   ...             ...
# 520378  erp|hardware|internet|it management|saas|web h...               0
# 520379                                                NaN               0
# 520380                                   machine learning               0
# 520381                                                NaN               0
# 520382                                                NaN               0
# 520383                                                NaN               0
# 520384                                                NaN               0
# 520385                                                NaN               0
# 520386                                         consulting               0
# 520387                                                NaN               0
# 520388                                     transportation               0
# 520389                               electronics|software               0
# 520390                                                NaN               0
# 520391                                                NaN               0
# 520392                                  big data|internet               0
# 520393                brewing|craft beer|wine and spirits               0
# 520394            3d printing|3d technology|manufacturing               0
# 520395                           digital media|journalism               0
# 520396         energy|energy efficiency|energy management               0
# 520397                           logistics|transportation               0
# 520398                       tourism|travel|travel agency               0
# 520399                                                NaN               0
# 520400                                                NaN               0
# 520401                                                NaN               0
# 520402                                                NaN               0
# 520403                                                NaN               0
# 520404                                                NaN               0
# 520405                                                NaN               0
# 520406                                                NaN               0
# 520407                                                NaN               0
#
#        employee_count  founded_on
# 0       10001-1000000  1968-07-18
# 1                   -  1968-01-01
# 2       10001-1000000  1974-04-04
# 3               11-50  1982-02-14
# 4                   -         NaN
# 5       10001-1000000  1937-08-28
# 6              51-100  1947-01-01
# 7          5001-10000  1982-01-01
# 8                   -  1979-01-01
# 9                   -         NaN
# 10          1001-5000  1981-01-01
# 11                  -         NaN
# 12              11-50  1979-01-01
# 13              11-50  1984-08-12
# 14                  -         NaN
# 15         5001-10000  1978-01-01
# 16                  -  1981-01-05
# 17               1-10  1967-01-01
# 18           501-1000  1978-01-01
# 19                  -         NaN
# 20            251-500  1973-01-01
# 21                  -  1960-01-01
# 22                  -         NaN
# 23                  -  1984-01-01
# 24                  -  1985-01-01
# 25      10001-1000000  1984-12-01
# 26                  -  1981-01-01
# 27      10001-1000000  1935-06-01
# 28      10001-1000000  1980-01-01
# 29              11-50  1980-01-01
# ...               ...         ...
# 520378         51-100  2006-06-24
# 520379              -  1984-01-01
# 520380           1-10  2010-07-01
# 520381           1-10  2015-08-05
# 520382              -  2012-01-01
# 520383              -         NaN
# 520384              -  2015-01-01
# 520385              -  1988-01-01
# 520386           1-10  2010-04-05
# 520387           1-10  1997-01-01
# 520388           1-10         NaN
# 520389         51-100  2012-04-20
# 520390              -  2008-01-01
# 520391           1-10  2014-09-01
# 520392           1-10  2012-01-01
# 520393           1-10  2009-01-01
# 520394              -         NaN
# 520395           1-10  2012-01-01
# 520396              -         NaN
# 520397     5001-10000  2000-01-01
# 520398              -  2013-01-01
# 520399              -         NaN
# 520400              -         NaN
# 520401              -         NaN
# 520402              -         NaN
# 520403              -         NaN
# 520404              -         NaN
# 520405              -         NaN
# 520406              -         NaN
# 520407              -         NaN
#
# [520408 rows x 5 columns]

# %%
df_investors.shape
df_investors.columns
# Out:
# Index([u'investor_name', u'primary_role', u'domain', u'country_code',
#        u'state_code', u'region', u'city', u'investor_type',
#        u'investment_count', u'total_funding_usd', u'founded_on', u'closed_on',
#        u'cb_url', u'logo_url', u'profile_image_url', u'twitter_url',
#        u'facebook_url', u'uuid', u'updated_at'],
#       dtype='object')

# %%
df_investors.sort_values('total_funding_usd', ascending = False)[['investor_name', 'investment_count', 'total_funding_usd', 'founded_on']]
# Out:
#                                    investor_name  investment_count  \
# 19                                 Goldman Sachs               572
# 1                                Sequoia Capital              1433
# 3                      New Enterprise Associates              1328
# 148                             Tencent Holdings               182
# 7               Kleiner Perkins Caufield & Byers               968
# 263                                     SoftBank               126
# 591                                      Alibaba                71
# 4                                  Intel Capital              1179
# 5                                 Accel Partners              1078
# 339                             Temasek Holdings               106
# 13203                     China Development Bank                 2
# 832                                   DST Global                53
# 136                      Tiger Global Management               201
# 129                               Warburg Pincus               209
# 27                           Andreessen Horowitz               521
# 413    KKR & Co. (Kohlberg Kravis Roberts & Co.)                94
# 321                               Morgan Stanley               110
# 13                     Bessemer Venture Partners               712
# 1142                        Silver Lake Partners                41
# 428                                T. Rowe Price                92
# 682                         Fidelity Investments                63
# 120         IVP (Institutional Venture Partners)               216
# 4435                        China Merchants Bank                 9
# 20                   Lightspeed Venture Partners               558
# 25                                       Venrock               538
# 56                       Oak Investment Partners               366
# 10                 Draper Fisher Jurvetson (DFJ)               783
# 16                             Greylock Partners               592
# 4525                                   HNA Group                 9
# 26                                     Benchmark               532
# ...                                          ...               ...
# 56234                           Zerimar Ventures                 0
# 56235                                       ZERO                 0
# 56236                                     Zero-F                 0
# 56237                          Zero One Ventures                 0
# 56238                        Zero Start Ventures                 0
# 56239              Zhongrong International Trust                 0
# 56240         Ziegler Lotsoff Capital Management                 0
# 56241                      Ziff Capital Partners                 0
# 56242                                ZINC SHOWER                 0
# 56243                                    Zinc.VC                 0
# 56244                              Zino Ventures                 0
# 56245    ZIP - Zagreb Entrepreneurship Incubator                 0
# 56246                                      Zitek                 0
# 56247                             ZL Investments                 0
# 56248                             ZMAG Institute                 0
# 56249                                 ZM Capital                 0
# 56250                                ZMT Capital                 0
# 56251                                Zoar Invest                 0
# 56252                               Zoic Capital                 0
# 56253                            Zonvon Ventures                 0
# 56254                           Zoozler Tech Lab                 0
# 56255                        Zoticon BioVentures                 0
# 56256                  ZSC Seed Accelerator Fund                 0
# 56257                                    ZS Fund                 0
# 56258                               Zubr Capital                 0
# 56259                         Zühlke Ventures AG                 0
# 56260                           Zukunft Ventures                 0
# 56261   Zur goldenen Forelle - Coworking Wien 14                 0
# 56262                     Zusho Venture Partners                 0
# 56263                        Zynik Capital Corp.                 0
#
#        total_funding_usd  founded_on
# 19          4.384606e+10  1869-01-01
# 1           4.278881e+10  1972-11-01
# 3           3.376353e+10  1977-01-01
# 148         3.223084e+10  1998-11-01
# 7           3.061267e+10  1972-03-01
# 263         2.820966e+10  1981-09-03
# 591         2.713037e+10  1999-06-01
# 4           2.568673e+10  1991-01-01
# 5           2.506624e+10  1983-01-01
# 339         2.405776e+10  1974-06-25
# 13203       2.185858e+10         NaN
# 832         1.781241e+10  2005-01-01
# 136         1.621745e+10  2001-04-13
# 129         1.612900e+10  1966-01-01
# 27          1.587769e+10  2009-06-01
# 413         1.566944e+10  1976-01-01
# 321         1.521932e+10  1935-01-01
# 13          1.511056e+10  1911-01-01
# 1142        1.431790e+10  1999-01-01
# 428         1.420063e+10  1937-04-01
# 682         1.384898e+10  1946-01-01
# 120         1.365870e+10  1980-01-01
# 4435        1.292629e+10  1987-01-01
# 20          1.249627e+10  2000-01-01
# 25          1.238366e+10  1969-01-01
# 56          1.236904e+10  1978-01-01
# 10          1.223915e+10  1985-10-01
# 16          1.208213e+10  1965-10-01
# 4525        1.205500e+10  1993-01-01
# 26          1.204200e+10  1995-01-01
# ...                  ...         ...
# 56234                NaN  2012-10-01
# 56235                NaN  2017-01-01
# 56236                NaN         NaN
# 56237                NaN  2014-07-25
# 56238                NaN         NaN
# 56239                NaN         NaN
# 56240                NaN  1991-01-01
# 56241                NaN  2015-01-01
# 56242                NaN  2012-01-01
# 56243                NaN  2017-01-01
# 56244                NaN         NaN
# 56245                NaN  2012-01-01
# 56246                NaN  2001-01-01
# 56247                NaN  2006-12-01
# 56248                NaN  2014-04-29
# 56249                NaN         NaN
# 56250                NaN  2016-09-01
# 56251                NaN         NaN
# 56252                NaN         NaN
# 56253                NaN         NaN
# 56254                NaN         NaN
# 56255                NaN         NaN
# 56256                NaN         NaN
# 56257                NaN  1985-01-01
# 56258                NaN  2010-01-01
# 56259                NaN  2011-01-01
# 56260                NaN  2016-09-15
# 56261                NaN         NaN
# 56262                NaN  2005-05-08
# 56263                NaN  1983-01-01
#
# [56264 rows x 4 columns]

# %%
df_events = pd.read_csv(data_folder + 'events.csv')
df_events['description'][0]
# Out:
# 'WasteTech (Waste and environmental Technology) exhibition and congress has become well-known to everyone engaged in waste treatment, environmental protection and renewable energy both in Russia and worldwide, especially in CIS and Baltic countries. \r\nThe first show WasteTech that was held in Moscow in September 1999 had just 340 sq. m of exhibition space with 40 exhibitors. \r\nAt the very beginning WasteTech was focused exclusively on solid waste issues. The forthcoming show will cover the full range of topics: waste management and recycling, wastewater treatment, renewable energy, air quality, reclamation of contaminated sites, industrial cleaning, improvement of territories, labor safety.\r\n\r\nAs a result, WasteTech exhibition and congress has become the main forum for waste management, recycling, renewable energy and environmental technologies in Russia and CIS.\r\n\r\nWasteTech-2017 Facts&Figures\r\n\r\n- 207 exhibitors including 74 international companies\r\n- 3955 sq. m of exhibition space\r\n- 5236 visitors\r\n\r\nWasteTech also includes two specialised expositions (brands): \r\n- ScrapExpo - ferrous and non-ferrous metal - scrap recycling; \r\n- REnergo - renewable energy and will take place in parallel with the annual exhibition and conference CityPipe "Piping Systems for Municipal Infrastructure: Construction, Diagnostics, Repair and Operation"\r\n\r\nURLs:\r\n\r\nFacebook: https://go.evvnt.com/134985-1\r\n\r\nTwitter: https://go.evvnt.com/134985-2'

# %%
df_organizations.columns
# Out:
# Index([u'company_name', u'primary_role', u'permalink', u'domain',
#        u'homepage_url', u'country_code', u'state_code', u'region', u'city',
#        u'zipcode', u'address', u'status', u'short_description',
#        u'category_list', u'category_group_list', u'funding_rounds',
#        u'funding_total_usd', u'founded_on', u'first_funding_on',
#        u'last_funding_on', u'closed_on', u'employee_count', u'email', u'phone',
#        u'facebook_url', u'linkedin_url', u'cb_url', u'logo_url',
#        u'profile_image_url', u'twitter_url', u'alias', u'uuid', u'created_at',
#        u'updated_at'],
#       dtype='object')
